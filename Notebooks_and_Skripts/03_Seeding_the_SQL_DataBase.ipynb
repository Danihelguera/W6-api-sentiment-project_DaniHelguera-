# %% [markdown]
# ## 1. Importamos librerías

# %%
import pandas as pd
import sqlalchemy as alch
import os

# %% [markdown]
# ## 2. Tokens y conexión a BD SQL

# %%
from dotenv import load_dotenv
load_dotenv()
password = os.getenv("sql")

# %%
dbName="amazon_rating"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %% [markdown]
# Comprobamos la conexion y si podemos leer las tablas de la BBDD

# %%
list(engine.execute(f"SELECT * FROM amazon_rating.user_names"))
# Out:
# [(1, 'Adapter'),
#  (2, 'truman'),
#  (3, 'DaveZ'),
#  (4, 'Shacks'),
#  (5, 'explore42'),
#  (6, 'tklit'),
#  (7, 'Droi'),
#  (8, 'Kacy'),
#  (9, 'Weebee'),
#  (10, 'RoboBob'),
#  (11, 'tld2'),
#  (12, 'ralexander422'),
#  (13, 'RegE'),
#  (14, 'TommyL'),
#  (15, 'Teacheeor'),
#  (16, 'BudVette'),
#  (17, 'Linda'),
#  (18, 'BestBuyLover'),
#  (19, 'Alane'),
#  (20, 'Mynie'),
#  (21, 'SeanRyan'),
#  (22, 'jim9311'),
#  (23, 'Babym494'),
#  (24, 'Lecale'),
#  (25, 'Laser301'),
#  (26, 'doglover'),
#  (27, 'Dave'),
#  (28, 'James'),
#  (29, 'NIQUE88'),
#  (30, 'Awesomelena'),
#  (31, 'Ryno513'),
#  (32, 'ChrisV'),
#  (33, 'Firemedic'),
#  (34, 'GrandmaKay'),
#  (35, 'rick'),
#  (36, 'ProudOwner'),
#  (37, 'Gift'),
#  (38, 'Keykey'),
#  (39, 'Christine'),
#  (40, 'Dodgerfan1'),
#  (41, 'WayneRules'),
#  (42, 'Rksajw'),
#  (43, 'Stevedb'),
#  (44, 'BennyJames'),
#  (45, 'Chris'),
#  (46, 'Legs'),
#  (47, 'Ralpho'),
#  (48, 'TechMan'),
#  (49, 'auntscrappie'),
#  (50, 'grannybear'),
#  (51, 'TLMart'),
#  (52, 'Tuowls'),
#  (53, 'DSuite'),
#  (54, 'Veebee'),
#  (55, 'Richardm1981'),
#  (56, 'Greg'),
#  (57, 'Farmboy'),
#  (58, 'labinoh'),
#  (59, 'Timothy'),
#  (60, 'katt'),
#  (61, 'Patman'),
#  (62, 'Netiks'),
#  (63, 'Wanoo'),
#  (64, 'JoeAnn'),
#  (65, 'itstamaral'),
#  (66, 'danm'),
#  (67, 'harry'),
#  (68, 'Matt'),
#  (69, 'Monica'),
#  (70, 'TashaB'),
#  (71, 'Fredbear'),
#  (72, 'Devonna'),
#  (73, 'Andy'),
#  (74, 'Mike'),
#  (75, 'Manny'),
#  (76, 'robz'),
#  (77, 'Dtweeter'),
#  (78, 'Moorthy'),
#  (79, 'Ediddy'),
#  (80, 'Surya'),
#  (81, 'SandeepMeenu'),
#  (82, 'Magoo'),
#  (83, 'cbranham26'),
#  (84, '911got2buy'),
#  (85, 'tinkerbell'),
#  (86, 'CarolDD'),
#  (87, 'Duke'),
#  (88, 'Craig'),
#  (89, 'AnneG'),
#  (90, 'MRpopo'),
#  (91, 'Boopette'),
#  (92, 'Ebald'),
#  (93, 'TJMilw'),
#  (94, 'Sandi987'),
#  (95, 'smart1'),
#  (96, 'Forshizzlemynizzle'),
#  (97, 'Amylynn88'),
#  (98, 'PJWSTKTN'),
#  (99, 'MichVoss'),
#  (100, 'JENK201'),
#  (101, 'treehuggnmom'),
#  (102, 'Blikechrist16'),
#  (103, 'TerriVB'),
#  (104, 'shopgirl282'),
#  (105, 'mary'),
#  (106, 'washer'),
#  (107, 'Santablet'),
#  (108, 'GoodHopeGal'),
#  (109, 'Goldduster'),
#  (110, 'TheBigGuy'),
#  (111, 'peter'),
#  (112, 'sassysenior'),
#  (113, 'drdonut'),
#  (114, 'jm5658'),
#  (115, 'johnbgood'),
#  (116, 'MtnbikerCO'),
#  (117, 'Mark'),
#  (118, 'Dawna'),
#  (119, 'jimtech'),
#  (120, 'Lyric'),
#  (121, 'LazyParent'),
#  (122, 'hunni'),
#  (123, 'Rosario'),
#  (124, 'Buqui'),
#  (125, 'Drewsdad'),
#  (126, 'Brandon'),
#  (127, 'Money'),
#  (128, 'Ingie'),
#  (129, 'FireHD8Tablet'),
#  (130, 'Kara12'),
#  (131, 'Champ'),
#  (132, 'Mags'),
#  (133, 'Kid7735'),
#  (134, 'Magenta'),
#  (135, 'MarkH'),
#  (136, 'ks1104'),
#  (137, 'Epoks'),
#  (138, 'Ruebaby64'),
#  (139, 'Doug'),
#  (140, 'yagga'),
#  (141, 'rchat'),
#  (142, 'Sandrazztt'),
#  (143, 'reviewfortherewardspoints'),
#  (144, 'Noneya'),
#  (145, 'Figgy51'),
#  (146, 'Mikeydsl'),
#  (147, 'Angelala'),
#  (148, 'Ryan'),
#  (149, 'photodog'),
#  (150, 'xpolo21'),
#  (151, 'LT17'),
#  (152, 'mswallstreet'),
#  (153, 'suzannalicious'),
#  (154, 'Evo24'),
#  (155, 'Sail1'),
#  (156, 'turtlechele'),
#  (157, 'Candy'),
#  (158, 'Frumius'),
#  (159, 'Redbone'),
#  (160, 'Lulu'),
#  (161, 'Orion8881118'),
#  (162, 'Ravi'),
#  (163, 'Knifus66'),
#  (164, 'Abriryan'),
#  (165, 'alleycat'),
#  (166, 'Mijenx'),
#  (167, 'Apple'),
#  (168, 'juice'),
#  (169, 'akatay'),
#  (170, 'mjcooke32'),
#  (171, 'Smurf'),
#  (172, 'Oz87'),
#  (173, 'Jake'),
#  (174, 'Spider'),
#  (175, 'julian'),
#  (176, 'Lvangel10'),
#  (177, 'daspawn1'),
#  (178, 'Mom2twinsplus1'),
#  (179, 'Rocio15'),
#  (180, 'Tommy'),
#  (181, 'Slydawg'),
#  (182, 'Kml001983'),
#  (183, 'Bubba'),
#  (184, 'Samantha'),
#  (185, 'Truckowner'),
#  (186, 'Shell'),
#  (187, 'Nzmolina'),
#  (188, 'Technophile'),
#  (189, 'Jigs'),
#  (190, 'voltman'),
#  (191, 'Blonger'),
#  (192, 'Luda78'),
#  (193, 'mishka54'),
#  (194, 'dmcgimpsey'),
#  (195, 'GwenG'),
#  (196, 'sotired'),
#  (197, 'tinnygirl'),
#  (198, 'klthor'),
#  (199, 'kayakmeme'),
#  (200, 'Mhigb'),
#  (201, 'Fifa12machine'),
#  (202, 'shywon'),
#  (203, 'Slystone36'),
#  (204, 'eman2003'),
#  (205, 'ilmaestro'),
#  (206, 'SteveDickie'),
#  (207, 'Kdaniels'),
#  (208, 'sreekanth'),
#  (209, 'Rich'),
#  (210, 'Bangle78'),
#  (211, 'Momstreets'),
#  (212, 'katrina'),
#  (213, 'Rodman22'),
#  (214, 'Tabby'),
#  (215, 'Susie'),
#  (216, 'frank'),
#  (217, 'rksj0000'),
#  (218, 'blargh22'),
#  (219, 'Grobles7'),
#  (220, 'HondaVtec'),
#  (221, 'AZ23b'),
#  (222, 'hotleggs'),
#  (223, 'lily'),
#  (224, 'Mom23mnkees'),
#  (225, 'Roge'),
#  (226, 'Jonnya'),
#  (227, 'AL2016'),
#  (228, 'mcfry'),
#  (229, 'Tara585'),
#  (230, 'Mikikami'),
#  (231, 'MichAtty'),
#  (232, 'Jaes'),
#  (233, 'Mach1'),
#  (234, 'Sweet17'),
#  (235, 'turtle'),
#  (236, 'Letloverule'),
#  (237, 'Wellsmm'),
#  (238, 'mruiz9'),
#  (239, 'Anonymous'),
#  (240, 'Munoz425'),
#  (241, 'Vince'),
#  (242, 'Phonemannn'),
#  (243, 'ITGuy'),
#  (244, 'caran'),
#  (245, 'Yash'),
#  (246, 'Ruggy82'),
#  (247, 'Intheknow'),
#  (248, 'bobalouie101'),
#  (249, 'BobS'),
#  (250, 'justme'),
#  (251, 'Jamie'),
#  (252, 'Nater'),
#  (253, 'drumdude51'),
#  (254, 'dennislwalker'),
#  (255, 'Leticia'),
#  (256, 'Mattd80'),
#  (257, 'EddieG'),
#  (258, 'Scotty'),
#  (259, 'Cricket57'),
#  (260, 'Jimmy'),
#  (261, 'TS2Fast'),
#  (262, 'Catdaddy'),
#  (263, 'Stephanie95'),
#  (264, 'DiDi'),
#  (265, 'Upstart27'),
#  (266, 'TAT4'),
#  (267, 'Palmor'),
#  (268, 'TAii'),
#  (269, 'DDMM'),
#  (270, 'Xavi67'),
#  (271, 'RoRod1'),
#  (272, 'Factchecker'),
#  (273, 'Hello1'),
#  (274, 'JimmyC72'),
#  (275, 'notonfire1'),
#  (276, 'Aerow'),
#  (277, 'Buyer'),
#  (278, 'AMFJR'),
#  (279, 'GREAT'),
#  (280, 'folkboat'),
#  (281, 'kosch11'),
#  (282, 'Poudel'),
#  (283, 'JCFTJ'),
#  (284, 'Schambo'),
#  (285, 'devinhenkel'),
#  (286, 'afolc'),
#  (287, 'Sadiee'),
#  (288, 'Nagrom'),
#  (289, 'Grey'),
#  (290, 'HDelbrucke'),
#  (291, 'Family5'),
#  (292, 'SandiD'),
#  (293, 'DynaMan'),
#  (294, 'Christian'),
#  (295, 'Izzy'),
#  (296, 'ericandlisa'),
#  (297, 'hailey'),
#  (298, 'Weiser'),
#  (299, 'sg77'),
#  (300, 'Bob061'),
#  (301, 'KitKat'),
#  (302, 'Jimbo'),
#  (303, 'lmo28'),
#  (304, 'Nelee2'),
#  (305, 'Michelle'),
#  (306, 'darrenduke'),
#  (307, 'SpencerG'),
#  (308, 'Jedi007'),
#  (309, 'APDavid'),
#  (310, 'Trill4Lyf'),
#  (311, 'Bluedog101'),
#  (312, 'Rdeleon'),
#  (313, 'RICKCROW'),
#  (314, 'Edie'),
#  (315, 'blkbelt2'),
#  (316, 'Impala69'),
#  (317, 'Somdguy'),
#  (318, 'jules'),
#  (319, 'Robbie'),
#  (320, 'TheMaven'),
#  (321, 'Nancy'),
#  (322, 'PivotDave'),
#  (323, 'PowerHungry'),
#  (324, 'Dropp'),
#  (325, 'Syntfyd'),
#  (326, 'Crafty'),
#  (327, 'DJTrey'),
#  (328, 'Rach'),
#  (329, '1PersonalShopper'),
#  (330, 'KEMU'),
#  (331, 'LadyG0726'),
#  (332, 'April'),
#  (333, 'Gerry'),
#  (334, 'Jerichodaman'),
#  (335, 'purebusiness1'),
#  (336, 'kokirios77'),
#  (337, 'Ballernova'),
#  (338, 'gloutfita'),
#  (339, 'JoeLuwis'),
#  (340, 'Quonsolo'),
#  (341, 'Greensaber18'),
#  (342, 'SamtheSham'),
#  (343, 'Ganamurthy'),
#  (344, 'Govea219'),
#  (345, 'Mark19525'),
#  (346, 'Stoked75'),
#  (347, 'Fogue'),
#  (348, 'sally'),
#  (349, 'Cooldad'),
#  (350, 'Lumpy'),
#  (351, 'Eddie'),
#  (352, 'fungus42'),
#  (353, 'DMS13'),
#  (354, 'Quiilter'),
#  (355, 'BestBuyFAN'),
#  (356, 'djace'),
#  (357, 'Dcurtis7731'),
#  (358, 'allenr422000'),
#  (359, 'Obeliahubbard10'),
#  (360, 'Paul'),
#  (361, 'goglobal'),
#  (362, 'GeminiBrenda'),
#  (363, 'AJ9999'),
#  (364, 'Tang'),
#  (365, 'WoodMan196'),
#  (366, 'Stacey'),
#  (367, 'Gemini117'),
#  (368, 'Teri'),
#  (369, 'Kristian'),
#  (370, 'JOEY777'),
#  (371, 'Style'),
#  (372, 'Bella'),
#  (373, 'Quincy'),
#  (374, 'tamtts1948'),
#  (375, 'Lionking'),
#  (376, 'Tere'),
#  (377, 'Edalex1013'),
#  (378, 'Zephyr7'),
#  (379, 'Zoom'),
#  (380, 'Xaso'),
#  (381, 'RickN2244'),
#  (382, 'SKing'),
#  (383, 'notsolittlesnake'),
#  (384, 'Trey'),
#  (385, 'bigred268504'),
#  (386, 'Safetydude'),
#  (387, 'rovervic'),
#  (388, 'Dranktheapplejuice'),
#  (389, 'njguy'),
#  (390, 'Yesman'),
#  (391, 'Amethyst2380'),
#  (392, 'Gran'),
#  (393, 'KAM2013'),
#  (394, 'fanofBB'),
#  (395, 'darkangel1010'),
#  (396, 'adedios'),
#  (397, 'bworth37'),
#  (398, 'rob61'),
#  (399, 'Acidburn1'),
#  (400, 'Cjchumilo'),
#  (401, 'Bernie'),
#  (402, 'kristijudy'),
#  (403, 'Swami'),
#  (404, 'Krystinm'),
#  (405, 'Kindle'),
#  (406, 'evan'),
#  (407, 'MrDB'),
#  (408, 'KindleBuyer'),
#  (409, 'verybusymom3'),
#  (410, 'Patrick'),
#  (411, 'Greybeard'),
#  (412, 'Whiz'),
#  (413, 'flex3117'),
#  (414, 'DLynne'),
#  (415, 'Bdogg'),
#  (416, 'Hung'),
#  (417, 'gdallen58'),
#  (418, 'RoosterRock'),
#  (419, 'MTPockets'),
#  (420, 'Meme'),
#  (421, 'patn'),
#  (422, 'Sparky'),
#  (423, 'Bturner'),
#  (424, 'Armyacu'),
#  (425, 'Eric'),
#  (426, 'youngblood'),
#  (427, 'erockmon'),
#  (428, 'Jojo'),
#  (429, 'Jaybeecruise'),
#  (430, 'Economessed'),
#  (431, 'Belle'),
#  (432, 'icanjp'),
#  (433, 'jerrynindy'),
#  (434, 'Readaholic'),
#  (435, 'BarbLilly'),
#  (436, 'Rat1m'),
#  (437, 'Rolanddet'),
#  (438, 'Burt3475'),
#  (439, 'Papi2000'),
#  (440, 'Acmw'),
#  (441, 'microwave'),
#  (442, 'Mamaw'),
#  (443, 'gina1228'),
#  (444, 'Happy60'),
#  (445, 'Salsajammer'),
#  (446, 'Panther'),
#  (447, 'Mibellazobo'),
#  (448, 'Danny'),
#  (449, 'Nede'),
#  (450, 'Fish'),
#  (451, 'RAMTOO'),
#  (452, 'DLC320'),
#  (453, 'austin512'),
#  (454, 'Itsy'),
#  (455, 'jessxhart'),
#  (456, 'DerrickC'),
#  (457, 'Cheryl'),
#  (458, 'Mila'),
#  (459, 'Edge'),
#  (460, 'Fran'),
#  (461, 'AJ10'),
#  (462, 'semojr'),
#  (463, 'TarHeelMan'),
#  (464, 'Zach'),
#  (465, 'Crys'),
#  (466, 'HFCU'),
#  (467, 'MelK'),
#  (468, 'techy'),
#  (469, 'slash'),
#  (470, 'lauerranch'),
#  (471, 'Mere'),
#  (472, 'anil'),
#  (473, 'khob'),
#  (474, 'JGDomke'),
#  (475, 'maintenance'),
#  (476, 'BobbyK'),
#  (477, 'natenkatesmom'),
#  (478, 'Buyer1'),
#  (479, 'aiti'),
#  (480, 'John'),
#  (481, 'Omak'),
#  (482, 'chxfhx'),
#  (483, 'AG025'),
#  (484, 'Techguy8552'),
#  (485, 'greeneyes'),
#  (486, 'manielmoth'),
#  (487, 'Tiffers'),
#  (488, 'TACO'),
#  (489, 'grandpa'),
#  (490, 'BestBuyMember'),
#  (491, 'Ricardo1agui'),
#  (492, 'Kk4movies'),
#  (493, 'Sweetestnurse'),
#  (494, 'vickybee'),
#  (495, 'Chavez'),
#  (496, 'Pame'),
#  (497, 'rcuti'),
#  (498, 'Tasharazzi'),
#  (499, 'Andersonlloyd2'),
#  (500, 'Mavsfan09'),
#  (501, 'Kari93'),
#  (502, 'tealady'),
#  (503, 'Dundee'),
#  (504, 'becky'),
#  (505, 'Hnterzexwife'),
#  (506, 'ISUgal'),
#  (507, 'Bearman'),
#  (508, 'PaulN'),
#  (509, 'kcladyz'),
#  (510, 'ArthurEdmonds'),
#  (511, 'Mia1'),
#  (512, 'GvilleGuy'),
#  (513, 'Mrspooh'),
#  (514, 'winstonsdad'),
#  (515, 'goldenApe4'),
#  (516, 'Steve2111'),
#  (517, 'Robin'),
#  (518, 'Sandy'),
#  (519, 'MARCUS'),
#  (520, 'Vinay'),
#  (521, 'GGinBC'),
#  (522, 'Fezzybear'),
#  (523, 'Deanna58'),
#  (524, 'LexusTech'),
#  (525, 'AngieB'),
#  (526, 'Kld653'),
#  (527, 'Gigi'),
#  (528, 'gary'),
#  (529, 'Kingjames1'),
#  (530, 'Randy2'),
#  (531, 'Willis1969'),
#  (532, 'nikhil34'),
#  (533, 'tablet'),
#  (534, 'Jazthepanda'),
#  (535, 'MoutainMike'),
#  (536, 'Phil'),
#  (537, 'SamD'),
#  (538, 'malabrot'),
#  (539, 'MrMig'),
#  (540, 'debugy'),
#  (541, 'Gasman33'),
#  (542, 'Gram'),
#  (543, 'Scangen'),
#  (544, 'lindee'),
#  (545, 'Susan'),
#  (546, 'Melmomof3'),
#  (547, 'DCMack'),
#  (548, 'jubyjack'),
#  (549, 'Shelleyp'),
#  (550, 'barbie54'),
#  (551, 'Jwolfgr'),
#  (552, 'Xiitz'),
#  (553, 'Happyguy'),
#  (554, 'TimothyDon'),
#  (555, 'pdskee'),
#  (556, 'GrannyL'),
#  (557, 'shawbonez'),
#  (558, 'tre48'),
#  (559, 'Miller'),
#  (560, 'Lng10'),
#  (561, 'BrianP'),
#  (562, 'Zumbaqueen'),
#  (563, 'Spencer122799'),
#  (564, 'LoveBestBuy'),
#  (565, 'Wilemena1'),
#  (566, 'Posey'),
#  (567, 'Diver440'),
#  (568, 'ExpatTyke'),
#  (569, 'kkarter1'),
#  (570, 'simmer'),
#  (571, 'johnbestbuy'),
#  (572, 'Nt1980'),
#  (573, 'Themetedun'),
#  (574, 'Elmo'),
#  (575, 'Hobbymama'),
#  (576, 'BBloyal'),
#  (577, 'abby'),
#  (578, 'JohnN'),
#  (579, 'Alfeca'),
#  (580, 'Fishingbabe'),
#  (581, 'Klburg'),
#  (582, 'ChucklesTheCheat')]

# %%
list(engine.execute(f"SELECT * FROM amazon_rating.product_names"))
# Out:
# [(1, 'All-New Fire HD 8 Tablet 8 HD Display Wi-Fi 16 GB - Includes Special Offers Magenta')]

# %%
list(engine.execute(f"SELECT * FROM amazon_rating.ratings"))
# Out:
# [(1, '5', 'This product so far has not disappointed. My children love to use it and I like the ability to monitor control what content they see with ease.', 'Kindle', datetime.date(2017, 1, 13), 1, 1, 1),
#  (2, '5', 'great for beginner or experienced person. Bought as a gift and she loves it', 'very fast', datetime.date(2017, 1, 13), 1, 1, 2),
#  (3, '5', 'Inexpensive tablet for him to use and learn on step up from the NABI. He was thrilled with it learn how to Skype on it already...', 'Beginner tablet for our 9 year old son.', datetime.date(2017, 1, 13), 1, 1, 3),
#  (4, '4', 'I´ve had my Fire HD 8 two weeks now and I love it. This tablet is a great value.We are Prime Members and that is where this tablet SHINES. I love bei ... (295 characters truncated) ... NELY AWESOME running at only 7.7mm thick and the smooth glossy feel on the back it is really amazing to hold its like the futuristic tab in ur hands.', 'Good!!!', datetime.date(2017, 1, 13), 1, 1, 4),
#  (5, '5', 'I bought this for my grand daughter when she comes over to visit. I set it up with her as the user entered her age and name and now Amazon makes sure ... (314 characters truncated) ... additional speed and capacity but when it comes to the basics this tablets does everything that most people will ever need at a fraction of the cost.', 'Fantastic Tablet for kids', datetime.date(2017, 1, 12), 1, 1, 5),
#  (6, '5', 'This amazon fire 8 inch tablet is the perfect size. I purchased it for my husband so that he has a bigger screen than just his phone. He had gotten me one a few years ago so I knew it would be a good purchase.', 'Just what we expected', datetime.date(2017, 1, 12), 1, 1, 6),
#  (7, '4', 'Great for e-reading on the go nice and light weight and for the price point given definitely worth the purchase.', 'great e-reader tablet', datetime.date(2017, 1, 12), 1, 1, 7),
#  (8, '5', 'I gave this as a Christmas gift to my inlaws husband and uncle. They loved it and how easy they are to use with fantastic features!', 'Great for gifts', datetime.date(2017, 1, 12), 1, 1, 8),
#  (9, '5', 'Great as a device to read books. I like that it links with my borrowed library e-books. Switched from another popular tablet brand and I am happy with the choice I made. It took some time to get books from my previous non-Kindle reader but finally figured out a way!', 'Great for reading', datetime.date(2017, 1, 23), 1, 1, 9),
#  (10, '5', 'I love ordering books and reading them with the reader.', 'Great and lightweight reader', datetime.date(2017, 1, 23), 1, 1, 10),
#  (11, '4', 'Not easy for elderly users cease of ads that pop up.', 'nice tablet for the price', datetime.date(2017, 1, 23), 1, 1, 11),
#  (12, '5', 'Excellent product. Easy to use large screen makes watching movies and reading easier.', 'Excellent product', datetime.date(2017, 1, 23), 1, 1, 12),
#  (13, '4', 'Wanted my father to have his first tablet and this is a very good value. He can watch movies and play a few games. Easy enough for him to use.', 'Great Value', datetime.date(2017, 1, 23), 1, 1, 13),
#  (14, '5', 'Simply does everything I need. Thank youAnd silk works wonders', 'Excellect', datetime.date(2017, 1, 23), 1, 1, 14),
#  (15, '5', 'Got it as a present and love the size of the screen', 'Living It', datetime.date(2017, 1, 23), 1, 1, 15),
#  (16, '5', 'The kindle is easiest to use graphics and screen crisp clear brilliant colors.', 'Favorite of any tablet', datetime.date(2017, 1, 23), 1, 1, 16),
#  (17, '4', 'nice reader. almost perfect for what i want/need. good bargain', 'good', datetime.date(2017, 1, 24), 1, 1, 17),
#  (18, '4', 'I really like this tablet. I would have given 5 stars but sometimes you have to push start several times after you unlock the screen and it is a little annoying.', 'Nice Tablet for the Price', datetime.date(2017, 1, 24), 1, 1, 18),
#  (19, '5', 'Great video quality lots of fun apps fun for the whole family', 'Great quality tablet', datetime.date(2017, 1, 24), 1, 1, 19),
#  (20, '5', 'Love love love my kindle fire 8.....this is what my 9 yr old granddaughter said when I bought this for her at Christmas..we have purchased kindled in ... (32 characters truncated) ... the best....love the fact that you can now use a memory card in it...that helps so much when you use it for books...games...music and viedos...thanks', 'Kindle fire 8', datetime.date(2017, 1, 24), 1, 1, 20),
#  (21, '5', 'Excellent tablet with nice screen. I wish Amazon would pre install the play store this would have been perfect.', 'Excellent reader', datetime.date(2017, 1, 24), 1, 1, 21),
#  (22, '5', 'Preloaded with the reading app from Kindle but expandable with other apps. Perfect for travel. Carry your library games and productivity apps in a small footprint.', 'Best Tablet Choice', datetime.date(2017, 1, 24), 1, 1, 22),
#  (23, '5', 'Very happy with this product and easy to use..picture is clear takes great pictures..', 'Great size..', datetime.date(2017, 1, 24), 1, 1, 23),
#  (24, '5', 'My grandchildren are home schooled and utilize the tables for many learning apps! They LOVE using them as it makes them feel so grown up! The tablets are a great leaning tool and they are receiving many benefits from them!', 'Great tablet for kids!', datetime.date(2017, 1, 24), 1, 1, 24),
#  (25, '5', 'Great size easy to carry for traveling. Need to spend more time Looking into apps for contact manegement interactive calenders and most important music storage and use.', 'First Tablet. Lots of possibilities.', datetime.date(2017, 1, 27), 1, 1, 25),
#  (26, '4', 'I purchased this when my last tablet died. It meets all basic needs and the price was great.', 'Great price for a basic tablet.', datetime.date(2017, 1, 27), 1, 1, 26),
#  (27, '4', 'Perfect for downloading and reading books !! Perfect size and has a nice bright screen.', 'Great quality tablet', datetime.date(2017, 1, 27), 1, 1, 27),
#  (28, '5', 'I was surprised when I learned of the capabilities of this device. Now my husband has more access to his desktop and I am doing things which I couldn´t on his device.', 'Excellent for simple games and social media.', datetime.date(2017, 1, 27), 1, 1, 28),
#  (29, '5', 'I got it for my son. Its user friendly and durable.', 'I like it', datetime.date(2017, 1, 27), 1, 1, 29),
#  (30, '5', 'The visual quality on the Fire 8 HD is amazing. It runs very fast and is easy to use very durable.', 'Great Tablet', datetime.date(2017, 1, 27), 1, 1, 30),
#  (31, '5', 'If your looking for a affordable gift this is it!.', 'looking for a great gift that is affordable.', datetime.date(2017, 1, 27), 1, 1, 31),
#  (32, '5', 'This is a great tablet for the price would recommend it to anyone looking for a basic tablet.', 'Great Tablet Great Price', datetime.date(2017, 1, 27), 1, 1, 32),
#  (33, '4', 'Works great. Love the portability of books. Overall great product', 'Great product', datetime.date(2017, 2, 3), 1, 1, 33),
#  (34, '5', 'I am still learning all the things I can do with my new Kindle Fire. It is so much better (lighter in weight and easier to use) than my old tablet.', 'Enjoying my new tablet', datetime.date(2017, 2, 3), 1, 1, 34),
#  (35, '5', 'Just the right size for reading books and playing some games.', 'Perfect size', datetime.date(2017, 2, 3), 1, 1, 35),
#  (36, '5', 'I love everything about this tablet! The imaging is sharp and clear. It´s fast and light weight. Love it!', 'Love my Amazon Fire HD 8 tablet', datetime.date(2017, 2, 3), 1, 1, 36),
#  (37, '4', 'Overall a nice product for traveling purposes Value for money', 'Great product', datetime.date(2017, 2, 3), 1, 1, 37),
#  (38, '5', 'My children love this table great quality of pictures excellent camera', 'Great for kids', datetime.date(2017, 2, 3), 1, 1, 38),
#  (39, '5', 'I bought 3 tablets and my family was not disappointed.', 'Great Tablet', datetime.date(2017, 2, 3), 1, 1, 39),
#  (40, '5', 'Great tablet fast screen good size never gives me problem', 'Great', datetime.date(2017, 2, 3), 1, 1, 40),
#  (41, '4', 'Bought this for my 87 year old grandmother who wanted to be able to play games and read books from the library. My aunt lives with her and can help h ... (109 characters truncated) ... ne other than a hardcore user that wants the latest and greatest tech. if you are tech saavy you can do more with these Fire tablets than advertised.', 'Good low cost option for tablet', datetime.date(2017, 2, 6), 1, 1, 41),
#  (42, '5', 'This is exactly what the person wanted as a gift and she enjoys using it.', 'Enjoyable', datetime.date(2017, 2, 6), 1, 1, 42),
#  (43, '4', 'Does all basic functions of a tablet. Hardcore users may want an iPad.', 'Good starter tablet', datetime.date(2017, 2, 6), 1, 1, 43),
#  (44, '4', 'Works great for a simple tablet. Not a huge fan of the silk browser but it could be worse! I am very happy with my purchase!', 'Priced to sell nice little unit!', datetime.date(2017, 2, 5), 1, 1, 44),
#  (45, '5', 'It´s fast and easy to use. This is my second kindle fire .', 'Love the camera', datetime.date(2017, 2, 5), 1, 1, 45),
#  (46, '4', 'More flexibility than a Kindle and bigger screen. Like it because I can surf the web and download and read books.', 'Was looking for an Kindle', datetime.date(2017, 2, 5), 1, 1, 46),
#  (47, '5', 'For the money you cannot beat this tablet. Full of features picture quality is great and very fast speed while using the internet.', 'great tablet for the money', datetime.date(2017, 2, 5), 1, 1, 47),
#  (48, '5', 'Easy to use solid build sharp HP screen for movies. Who needs more?', 'Nice HD tablet', datetime.date(2017, 2, 5), 1, 1, 48),
#  (49, '5', 'Tablet is perfect for beginners who just want basic', 'Ease of use', datetime.date(2017, 3, 20), 1, 1, 49),
#  (50, '5', 'this is my first tablet .. love it .. actually read my first e-book on it .. large screen easy to read & play games .. fits nicely in my purse', 'Awesome', datetime.date(2017, 3, 20), 1, 1, 50),
#  (51, '4', 'This 8 inch Fire is definitely better than the cheaper 7 inch. It works fine enough for teens to play games and watch movies.', 'Decent Tablet for Teen Basic Games', datetime.date(2017, 3, 20), 1, 1, 51),
#  (52, '4', 'Great tablet for under $100. Does not have the highest specs but gets the job done for lite tablet users.', 'Great tablet for the price', datetime.date(2017, 3, 20), 1, 1, 52),
#  (53, '4', 'I purchased the kindle fire because I needed a entertainment only device for long flights. This device is the perfect size for travel and easy to use ... (117 characters truncated) ... I would not recommend it because the available apps are limited . My only complaint about this device is that if it freezes it is difficult to reset.', 'Fire Tablet - great for entertainment', datetime.date(2017, 3, 20), 1, 1, 53),
#  (54, '4', 'This fire tablet has long battery life. Reasonable fast', 'Good for Kids', datetime.date(2017, 3, 19), 1, 1, 54),
#  (55, '4', 'Got this for my wife and she loves it. She had the previous generation and this one is a giant keep forward.', 'My wife loves it.', datetime.date(2017, 3, 19), 1, 1, 55),
#  (56, '5', 'Sleek packaging easy set up and great for anyone who wants a e reader with more to offer.', 'Great!', datetime.date(2017, 3, 19), 1, 1, 56),
#  (57, '5', 'Best and most affordable option of all the Kindle devices available.', 'Great Device', datetime.date(2017, 6, 3), 1, 1, 57),
#  (58, '5', 'I did not want to get a new kindle but my old one would not charge or show a charge anymore. I could not depend on it for any length of time so I fin ... (131 characters truncated) ... me from the Amazon store. However everything I had on the old kindle transferred to the new one. I am still learning all about it but so far so good.', 'A nice upgrade to my old kindle.', datetime.date(2017, 6, 3), 1, 1, 58),
#  (59, '5', 'My daughter likes this tablet to play her online games!', 'Present for my daughter & she loves it!', datetime.date(2017, 6, 3), 1, 1, 59),
#  (60, '4', 'Easy to figure out and used it extensively on my vacation.', 'Great little device', datetime.date(2017, 6, 3), 1, 1, 60),
#  (61, '5', 'Excellent tablet to leave at my easel and display reference photos. It´s light enough to velcro to a articulating stand (so I can position the tablet right next to my canvas). It´s cheap enough to not worry about. I love it for the price.', 'Perfect for artist reference photos!', datetime.date(2017, 6, 3), 1, 1, 61),
#  (62, '5', 'I bought this wanting for books comics and movies and it has not disappoint ever since', 'Great tablet for what it´s worth', datetime.date(2017, 6, 3), 1, 1, 62),
#  (63, '5', 'My 4 year old Grandson loves his Kindle. He had to have one after his sister got one.', 'Great tablet', datetime.date(2017, 6, 3), 1, 1, 63),
#  (64, '5', 'Easy to use. As a beginner I found this pad very good. Enjoy the kindle app.', 'Good pad for a beginner', datetime.date(2017, 6, 3), 1, 1, 64),
#  (65, '4', 'This Kindle does what I need it to do. The camera could be better but overall I am pretty happy with my purchase.', 'Pretty Decent', datetime.date(2016, 12, 15), 1, 1, 65),
#  (66, '5', 'Purchased this for my daughter to do more reading. It has so much more options for her if she wants.', 'Great deal', datetime.date(2016, 12, 15), 1, 1, 66),
#  (67, '5', 'this is a great tablet for the price. my kid loves it does alot reading on it.', 'great for my kids', datetime.date(2016, 12, 15), 1, 1, 67),
#  (68, '4', 'I was really hoping that this would be faster than some other inexspensive tablets I´ve had. I mainly use it for email though and it does the job.', 'Can be slow', datetime.date(2016, 12, 15), 1, 1, 68),
#  (69, '4', 'Bought as a Christmas gift for someone. I bought iPad as well. Will update when it´s used.', 'Great price', datetime.date(2016, 12, 15), 1, 1, 69),
#  (70, '5', 'Great tablet for the price. It is easy to navigate.', 'Kindle Fire tablet', datetime.date(2016, 12, 15), 1, 1, 70),
#  (71, '5', 'I believe that this will be very useful during my husbands recovery from foot surgery.', 'Great tablet for a beginner', datetime.date(2016, 12, 15), 1, 1, 71),
#  (72, '4', 'This is something that is useful if your looking for something to take along trips', 'Hd tablet', datetime.date(2016, 12, 15), 1, 1, 72),
#  (73, '5', 'This is a wonderful device. I love the extra capabilities and apps.', 'Great tablet', datetime.date(2016, 12, 16), 1, 1, 73),
#  (74, '4', 'Decent tablet. Access to kindle and pretty much all your google apps.', 'Pretty nice', datetime.date(2016, 12, 16), 1, 1, 74),
#  (75, '5', 'I am very happy with this tablet. The worst thing is that my steals it all the time. Lol', 'Great tablet', datetime.date(2016, 12, 16), 1, 1, 75),
#  (76, '5', 'A family member has vision problems. They had seen/used the Kindle of another family member - especially the ability to scale text. This device will make it possible to read which she has had extreme difficulty doing.', 'A gift for Grandma', datetime.date(2016, 12, 16), 1, 1, 76),
#  (77, '5', 'Easy setup and connect to WIFI. Great viewing area. Easy to read in bright places.', 'Great Price for the reader', datetime.date(2016, 12, 16), 1, 1, 77),
#  (78, '5', 'I got this fire for my friend who wants to buy kindle..this serves both Kindle and Tab... very nice and very cheap..worth for what i paid.. I highly recommend this for beginners', 'Great Tab!!!!', datetime.date(2016, 12, 16), 1, 1, 78),
#  (79, '5', 'Really enjoyed the price value of this tablet versus ipad', 'Awesome tablet for kids', datetime.date(2016, 12, 16), 1, 1, 79),
#  (80, '5', 'Amazing tablet with fast processor. It looks great... got good deal', 'Great basic tab', datetime.date(2016, 12, 15), 1, 1, 80),
#  (81, '5', 'We got this for our 5 year old and this is really great for the price. Works like a charm!!', 'Good tablets for kids', datetime.date(2017, 6, 3), 1, 1, 81),
#  (82, '5', 'I find it easy to use but the kindle does not come with instructions so you have to find your way around.', 'I love my kindle......best investment I have made', datetime.date(2017, 6, 3), 1, 1, 82),
#  (83, '4', 'I bought this because I was tired of watching Youtube and Twitch on my phone. Excellent display sound is decent-not great but you can always buy a sp ... (97 characters truncated) ... he app works fine on my phone but for some reason on this tablet it freezes and is unusable. All things considered for 65 bucks it´s hard to be beat.', 'Excellent for it´s price point.', datetime.date(2017, 5, 9), 1, 1, 83),
#  (84, '5', 'I love this tablet. The battery life last a long time. I use my Amazon Kindle Fire predominately for watching movies on Amazon Prime Netflix´s and ch ... (185 characters truncated) ...  tablet if you are looking for something to watch movies and checking emails. I would definitely recommend this tablet to friends and family members.', 'Excellent HD8 16GB Tablet', datetime.date(2017, 5, 9), 1, 1, 84),
#  (85, '5', 'My daughter loves this kindle she does so much with itwell worth the money.', 'Kindle fire hd', datetime.date(2017, 5, 8), 1, 1, 85),
#  (86, '5', 'Was looking for a tablet that was highly portable & could run my DIRECTTV app & stream videos. (Other electronics I have are much older versions). Sa ... (21 characters truncated) ... is model to me based on personal experience. I am still learning all its functions but so far it seems easy to use & is doing what it promised to do.', 'First Amazon FIRE', datetime.date(2017, 5, 8), 1, 1, 86),
#  (87, '5', 'This is my second Fire the other one is now retired. I like having HD. Works just fine.', 'good price', datetime.date(2017, 5, 8), 1, 1, 87),
#  (88, '5', 'My wife bought this for me for my birthday. I enjoy reading biographys which usually have color photos. The regular Kindle make the pics black and wh ... (38 characters truncated) ...  me to see the color photos. I also love the night feature when I´m in bed reading. I no longer need a light on to read or need to hold a large book.', 'Love it', datetime.date(2017, 5, 7), 1, 1, 88),
#  (89, '5', 'Thanks to a knowledgeable low-pressure salesperson I was ready to buy my first tablet. This one was the right price (on sale) and I have not been dis ... (116 characters truncated) ... books. It stays charged for days even with regular use. I recommend it as an inexpensive and very satisfactory alternative to more expensive tablets.', 'Easy to learn to use its many features.', datetime.date(2017, 5, 7), 1, 1, 89),
#  (90, '5', 'It´s a great tablet for the price. Don´t expect it to be as fast more expensive ones. It´s meant for casual use and it does a great job at that. For  ... (666 characters truncated) ... xpensive table that works great. For the money you will love it but don´t get upset that is doesn´t run as fast as a $500 tablet. That´s not its job.', 'Great little tablet', datetime.date(2017, 5, 7), 1, 1, 90),
#  (91, '4', 'Bought it for my 10 yr old granddaughter. Does everything she wants it to do in a tablet.', 'Granddaughter loves it!', datetime.date(2017, 1, 6), 1, 1, 91),
#  (92, '5', 'Very easy to use tablet. Lots of apps and game available.', 'Easy to use', datetime.date(2017, 1, 6), 1, 1, 92),
#  (93, '5', 'We love the FreeTime settings for kids on the newer Kindle Fires. I was able to create a login for each of our kids as well as myself and set limits  ... (489 characters truncated) ... o continually monitor every moment. By the way FreeTime kids settings are available without having to subscribe to their FreeTime app access plan. :)', 'Great tablet for kids!', datetime.date(2017, 1, 6), 1, 1, 93),
#  (94, '5', 'Great tablet very clear picture. Would buy again.', 'Love it!', datetime.date(2017, 1, 6), 1, 1, 94),
#  (95, '4', 'Good reader which is why I bought it. Ads are annoying.', 'Good not great', datetime.date(2017, 1, 6), 1, 1, 95),
#  (96, '4', 'It´s a mini computer packed in a handheld devise. Applications load quickly and I am able to get my work completed while riding the commuter rail.', 'Think it is a good product', datetime.date(2017, 1, 6), 1, 1, 96),
#  (97, '4', 'Nice for a smaller tablet. It´s good for Internet surfing.', 'User friendly', datetime.date(2017, 1, 6), 1, 1, 97),
#  (98, '5', 'Purchased as a door prize gift given with a one year Amazon membership. The recipient loves it and says it performs very well. (As a past Amazon Fire ... (9 characters truncated) ...  i-Pad graduate I loved my Amazon Fire for more than 4 years without any problems. In fact I just recycled it on to my son and it runs like a champ).', 'Excellent -- purchased for door prize', datetime.date(2017, 1, 6), 1, 1, 98),
#  (99, '5', 'I have 4 other kinds of tables. This the best I have had. I can listen to music read a book listen to a book or watch movies/tv shows.', 'Very versatile tablet.', datetime.date(2017, 1, 6), 1, 1, 99),
#  (100, '5', 'Great product for the kids gaming apps parental controls to make sure you can monitor kids and prevent unwanted app purchases', 'Works great', datetime.date(2017, 1, 6), 1, 1, 100),
#  (101, '5', 'I purchased 2 of these tablets for my 6 and 8 year old. They were a Black Friday special for $59. They are perfect for the apps and games they wanted.', 'Great deal!', datetime.date(2017, 1, 6), 1, 1, 101),
#  (102, '5', 'Great product. Love the Amazon ecosystem. The Freetime subscription is a must', 'Awesome', datetime.date(2017, 1, 6), 1, 1, 102),
#  (103, '5', 'Needed something a bit larger than the 6+ to stream Netflix this was perfect!', 'Woks great!', datetime.date(2017, 1, 6), 1, 1, 103),
#  (104, '5', 'my husband bought this for me as a Christmas present. I couldn´t understand why he bought it because I already have a Kindle Fire.Once I opened it and got it going I loved all it could do plus the graphic is so much colorful than my older Kindle.', 'love it!!', datetime.date(2017, 1, 6), 1, 1, 104),
#  (105, '5', 'my grandson-8-loves this --the games and the books!', 'amazon fire', datetime.date(2017, 1, 6), 1, 1, 105),
#  (106, '4', 'Great product and I´m very satisfied with it. I recommend it to other people.', 'I´m happy with it', datetime.date(2017, 1, 6), 1, 1, 106),
#  (107, '4', 'I purchased this tablet for my niece for Christmas and she love it.', 'It´s a great item that I purchased as a Christmas.', datetime.date(2017, 1, 7), 1, 1, 107),
#  (108, '5', 'Easy to use responds quickly great screen brightness.', 'Love It!', datetime.date(2017, 1, 7), 1, 1, 108),
#  (109, '4', 'Great tablet but apps limited comparison of other tablets.', 'Disappointed no access to Apps without credit card', datetime.date(2017, 1, 7), 1, 1, 109),
#  (110, '5', 'Works as we thought it should. NO PROBLEMS. Good buying experience.', 'Daughter loves it', datetime.date(2017, 1, 7), 1, 1, 110),
#  (111, '4', 'We have the smaller one and been great. This one is even better because of the size.', 'Good size', datetime.date(2017, 1, 7), 1, 1, 111),
#  (112, '5', 'I am a prime member & I love this tablet. Very user friendly especially if you are a prime member with amazon. Not real tech savvy so I need all the  ... (201 characters truncated) ... f 10. Also easier to take around in the smaller size. Highly recommend especially if you subscribe to Amazon and are a prime member. Great benefits!!', 'Love this tablet!', datetime.date(2017, 1, 7), 1, 1, 112),
#  (113, '5', 'Got this for my wife. She loves the bigger screen and the better app management features that this one has over her earlier generation kindle. Definitely worth it!', 'bigger screen!', datetime.date(2017, 1, 7), 1, 1, 113),
#  (114, '5', 'Connects to home WiFi automatically. Many books and many games. Actually functions like a computer tablet. E-mail is a breeze.', 'Perfect size. Great resolution.', datetime.date(2017, 1, 7), 1, 1, 114),
#  (115, '5', 'Bought this to replace no-name budget tablet for my daughter. She loves this as it is much faster and has a better display than her old tablet. This  ... (1 characters truncated) ... s a wonderful value as it is faster has a better display and sound is a name brand and cost about the same ... what´s not to love about this product?', 'Daughter Loves This Tablet', datetime.date(2017, 1, 8), 1, 1, 115),
#  (116, '5', 'She loves this tablet. It works well unlike her bargain tablet which she tried to use previously and cost about the same. She likes the sound of it also! She enjoys the free games she downloaded and navigates the wev easily with it.', 'Great Tablet For My Wife', datetime.date(2017, 1, 8), 1, 1, 115),
#  (117, '4', 'It´s no iPad but it´s great for Netflix and some app games. I´m not worried about the kids getting their paws on it since it´s relatively inexpensive.', 'Great value for what you get', datetime.date(2017, 1, 8), 1, 1, 116),
#  (118, '2', 'Didn´t have some of the features I was looking for. Returned it the next day. May be good for others', 'Wasn´t for me', datetime.date(2017, 1, 8), 1, 1, 117),
#  (119, '5', 'I bought this for my daughter and she loves it. It´s speedy when loading books!', 'works fine for my youngest', datetime.date(2017, 1, 8), 1, 1, 118),
#  (120, '4', 'Purchased for my wife who reads a lot and truly enjoys the amazon fire.', 'Great tablet for the price', datetime.date(2017, 1, 8), 1, 1, 119),
#  (121, '4', 'A great Christmas gift the kids love the gifts...', 'Great for games', datetime.date(2017, 1, 8), 1, 1, 120),
#  (122, '5', 'Daughter got this as a present. It was easy to set up and display is great. Features allow us to limit her time on games web etc. while allowing her unlimited time to read', 'Bargain tablet', datetime.date(2017, 1, 8), 1, 1, 121),
#  (123, '5', 'I have enjoyed just learning how to use it. You´re never too old to learn new things.', 'I love it.', datetime.date(2017, 1, 11), 1, 1, 122),
#  (124, '5', 'bought for husband and he was surprised it does the work he needs it for', 'awesome convenient', datetime.date(2017, 1, 11), 1, 1, 123),
#  (125, '5', 'This was a birthday present and it was ideal for a traveler to read ebooks on while on the rood', 'Small And Compact', datetime.date(2017, 1, 11), 1, 1, 124),
#  (126, '5', 'My teenage daughter enjoyed her three year old 7 Kindle for recreation but wanted a larger screen for word processing. Paired this with a Bluetooth keyboard and she was thrilled.', 'Daughter´s new Kindle Fire HD8', datetime.date(2017, 1, 10), 1, 1, 125),
#  (127, '1', 'i Bought this around black friday for $60 hoping it would be awesome... it failed so hard i tried multiple different micro SD cards none of which wer ... (779 characters truncated) ... pay for... also hint the s-pen version has an extra 1 GB of ram over the non pen version... so you should get that if you can afford the extra $50...', 'TERRIBLE DONT BUY', datetime.date(2017, 1, 10), 0, 1, 126),
#  (128, '5', 'The People I purchased this for during Christmas Holiday LOVED IT...', 'Purchased as a Christmas Gift', datetime.date(2017, 1, 10), 1, 1, 127),
#  (129, '5', 'I purchased two of these for my kids ages 12 and 10. Forget the IPod touch. For the price this tablet can´t be beat! They can download games books and movies for free all included with my Amazon Prime membership. Awesome!!', 'A MUST if you have Amazon Prime', datetime.date(2017, 1, 10), 1, 1, 128),
#  (130, '5', 'my kids enjoy the Fire HD and they love the picture quality', 'Christmas present', datetime.date(2017, 1, 10), 1, 1, 129),
#  (131, '4', 'Bought two of these tablets for my nieces for Christmas after we had originally bought the Amazon fire 7 inch which had a virus after 3 days of purch ... (230 characters truncated) ... problems screen is big enough for little hands to maneuver and see on was the highlight of there Christmas and still is would definitely recommend it', 'Great tablet for kids', datetime.date(2017, 1, 23), 1, 1, 130),
#  (132, '5', 'Really like the updates this product has in comparison to my first one', 'Great update to my existing kindle', datetime.date(2017, 1, 23), 1, 1, 131),
#  (133, '5', 'Functionality and ease of use are outstanding right out of the the box. Super clear screen and weight is minimum and is a joy to use.', 'Excellent device', datetime.date(2017, 1, 23), 1, 1, 132),
#  (134, '5', 'This tablet is great for kids and adults who have little to no knowledge of computers. It handles easily and has plenty of storage', 'Works very well especially for non tech people', datetime.date(2017, 1, 23), 1, 1, 133),
#  (135, '5', 'My god sister has been using these for years.What to read more!', 'Great display', datetime.date(2017, 1, 23), 1, 1, 134),
#  (136, '5', 'The latest Amazon 8 HD tablet is a very good tablet for the price. The updated processor and extra memory (with expansion slot) allow for very good p ... (41 characters truncated) ...  for. Netflix Hulu browsing the internet and doing e-mails all work very smoothly. Would recommend to anyone looking for a very cost effective tablet', 'Amazon 8 HD Tablet', datetime.date(2017, 1, 23), 1, 1, 135),
#  (137, '5', 'totally worth the money has all the apps I use on a daily basis!', 'great buy!', datetime.date(2017, 1, 23), 1, 1, 136),
#  (138, '5', 'Good tablet. Wife loves it and would recommend....', 'Great tablet for readers', datetime.date(2017, 1, 23), 1, 1, 137),
#  (139, '5', 'I use mine mainly for its bigger screen. I do all the same things i do on my phone..but love the big screen. I bought one for eaxh of my nieces too.  ... (38 characters truncated) ... os..playing music..reading books. They bith love them! Im happy i got them for all of us. And always reccomend them to my friends for their kids too.', 'I bought one for me and one for each of my nieces.', datetime.date(2017, 1, 23), 1, 1, 138),
#  (140, '5', 'Amazon Fire HD8 is a great product for the price. I picked it up for $69 during the holiday shopping season. Replacing a 1st gen Samsung Tab 2. This thing is sooo much faster. Perfect size for reading Kindle books  emails and doing the social media thing.', 'Best bang for your buck!', datetime.date(2017, 1, 23), 1, 1, 139),
#  (141, '4', 'It was a good gift for the price and had many features and options', 'Good for the price', datetime.date(2017, 1, 23), 1, 1, 140),
#  (142, '4', 'Not as fancy as the ipad but a fraction of the cost works well with android system and all apps like on our android phones cant beat the price', 'Very good product so far', datetime.date(2017, 1, 23), 1, 1, 141),
#  (143, '5', 'My kids can play read watch movies and much more love it!!!', 'This tablet its awesome !!!!', datetime.date(2017, 1, 23), 1, 1, 142),
#  (144, '4', 'Great tablet for reading books but the bluetooth is hard to get working and there are much better tablets for games and movies', 'Good Tablet for Books', datetime.date(2017, 1, 23), 1, 1, 143),
#  (145, '5', 'I love this Kindle!! I am biased I think however I have had 3 previous ones I prefer Kindles to any other tablet', 'Awesome', datetime.date(2017, 1, 23), 1, 1, 144),
#  (146, '4', 'This is a great tablet for kids. I love that their time on the tablet can be restricted.', 'Great for kids', datetime.date(2017, 1, 23), 1, 1, 145),
#  (147, '4', 'Easy to use. Good size. Great eReader. Not so expensive that I worry about my kids using it.', 'Great value for pricing', datetime.date(2017, 1, 26), 1, 1, 45),
#  (148, '5', 'This Tablet was purchased for our Grandmother so she could play games and read books on.', 'Great', datetime.date(2017, 1, 26), 1, 1, 73),
#  (149, '5', 'Bought a few of these for Christmas gifts .Everyone is happy !Its a great device for the $$. Low price and great quality as always from FIRE devices.', 'Awesome Table for the $$', datetime.date(2017, 1, 26), 1, 1, 146),
#  (150, '4', 'I purchased this item for my husband and he has liked reading Kindle books on it and the other features like Silk etc. Light little tablet with good features.', 'Good little tablet with HD quality', datetime.date(2017, 1, 26), 1, 1, 147),
#  (151, '5', 'Bought this for our year end holiday party raffle prize pool. Great price and people always have a use for an amazon tablet. Came with Kaspersky for free as well which is a pretty generous complimentary add on.', 'Great raffle prize', datetime.date(2017, 1, 26), 1, 1, 148),
#  (152, '4', 'My 6 yr old daughter got this tablet from Santa for Christmas. So far she loves it a little too much perhaps.. I only use it to manage her account/pe ... (14 characters truncated) ... so far haven´t had any issues with it.. Software and HW not quite as refined as apple iPad products but what can you expect at the lower price point.', 'Good tablet for the money', datetime.date(2017, 1, 25), 1, 1, 149),
#  (153, '4', 'my opinion its a good option for the cost. Not as great as Apple Ipad but it costs so much less. Still can get good use', 'good portable device', datetime.date(2017, 1, 25), 1, 1, 150),
#  (154, '5', 'Has many educational apps I would definitely go into the settings if you´re a mother like me who Is a very strict of what your children watch on TV o ... (477 characters truncated) ... d on educational apps read books most of these apps are free to I also recommend NOT putting a payment method option other than that my kids loved it', 'Great funEducational appsbooksbrain teasers', datetime.date(2017, 1, 25), 1, 1, 151),
#  (155, '4', 'the hd feature is what sold me on this product along with the fact its a lotmore streamline than the older version that I have', 'this product has great features and good history', datetime.date(2017, 1, 30), 1, 1, 152),
#  (156, '5', 'Very nice for light internet browsing keeping on top of email viewing videos and reading e books which I like to get free from the library. Good brow ... (13 characters truncated) ... ery power fast charge. Very relaxing to sit in a comfy chair and read or browse. Has given me hours of enjoyment and information for a minimal price.', 'You get a lot for the price!', datetime.date(2017, 1, 30), 1, 1, 153),
#  (157, '5', 'I bought this for my wife to replace her old Kindle and she loves it. Much easier to read than an iPad and updated features make it a great purchase.', 'Great Reader', datetime.date(2017, 1, 29), 1, 1, 154),
#  (158, '5', 'Great tablet and price. Ordering online easy. Not happy took so long to receive though.', 'Easy to use.', datetime.date(2017, 1, 29), 1, 1, 155),
#  (159, '5', 'Best tablet good price nice looking. Ordering on line was easy.', 'Great tablet for anybody.', datetime.date(2017, 1, 29), 1, 1, 155),
#  (160, '5', 'I got this for my mom for Christmas. Every time I visit she shows me something else she can do with it. I´m so jealous I hope I get one.', 'jealous', datetime.date(2017, 1, 29), 1, 1, 156),
#  (161, '5', 'This is my fourth Kindle...upgrading each time. Mine goes everywhere with me and is used throughout the day. Wouldn´t be without it.', 'Kindle Fire HD 8', datetime.date(2017, 1, 29), 1, 1, 157),
#  (162, '5', 'We bought this for our son when he went to college. He is able to upload all of his books and other documents.', 'Great for college students', datetime.date(2017, 1, 29), 1, 1, 158),
#  (163, '5', 'I purchased it for my mother-in-law and she loves it it was easier for her to use and understand', 'I', datetime.date(2016, 11, 26), 1, 1, 159),
#  (164, '5', 'The Amazon Fire is amazing! Picture clarity and sound are excellent! I highly recommend this tablet! Love it!', 'AMAZON FIRE.....AMAZING!', datetime.date(2016, 11, 26), 1, 1, 160),
#  (165, '5', 'Sharp picture and easy to use. And a fantastic price', 'I love it', datetime.date(2016, 11, 26), 1, 1, 161),
#  (166, '4', 'I like this is great I bought it my friend he was pleased abount', 'Good', datetime.date(2016, 11, 26), 1, 1, 162),
#  (167, '4', 'I wanted a low cost but quality tablet and this one is a dream! Easy to navigate and excellent graphics.', 'FIRE HD Amazing', datetime.date(2016, 11, 26), 1, 1, 163),
#  (168, '5', 'This a great tablet for everyone. Plenty of memory for downloading. Great features all around.', 'Great tablet for the whole family', datetime.date(2016, 11, 26), 1, 1, 164),
#  (169, '5', 'I own two Nook tablets another Kindle and a Samsung and this is the best one yet. Excellent battery life. Lets me check emails the Web and with Kindle. books can be switched from reads to listens. Also works better than the Nook with audiobooks.', 'Great tablet-reasonably priced', datetime.date(2016, 11, 25), 1, 1, 165),
#  (170, '1', 'I bought this tablet for my 4 year old daughter. Too many advertisements. I would rather pay more and not have a single ad.', 'Ended up returning', datetime.date(2016, 11, 25), 0, 1, 166),
#  (171, '5', 'This is a step up from what my son was using. He said it does well and easy to use.', 'Good', datetime.date(2016, 12, 3), 1, 1, 167),
#  (172, '4', 'This is a good tablet for kids who are starting off', 'tablet', datetime.date(2016, 12, 3), 1, 1, 168),
#  (173, '5', 'I bought this for my 6 year old and it´s perfect. Faster & clearer than older versions.', 'It´s great I love it!', datetime.date(2016, 12, 2), 1, 1, 169),
#  (174, '5', 'Awesome good size large enough for games and photos', 'Nice tablet', datetime.date(2016, 12, 2), 1, 1, 170),
#  (175, '5', 'Great gift easy to use and she loves being able to take it anywhere', 'My mama´s BDay gift', datetime.date(2016, 12, 2), 1, 1, 171),
#  (176, '5', 'I bought this to replace the 7 inch version I lost in the airport. I wanted the bigger screen and the higher resolutions. It is much when loading gam ... (343 characters truncated) ... oth so great for surfing try he net or listening to music. The 8 in screen is perfect for lying in bed and watching my show. I highly recommend this.', 'Best Buy for your buck', datetime.date(2016, 12, 2), 1, 1, 172),
#  (177, '5', 'Intuitive user interface rapid online access through well designed features light weight ergonomic buttons for volume and power. Overall a thoroughly well designed excellent priced device for web browsing and social media.', 'Get Online without Hassle', datetime.date(2016, 12, 2), 1, 1, 173),
#  (178, '4', 'PURCHASED THIS WITH A STORE CREDIT AND LIKE IT A LOT. COMPARES WELL WITH MORE EXPENSIVE TABLETS..RECOMMENDED', 'nice product for the money', datetime.date(2016, 12, 2), 1, 1, 174),
#  (179, '5', 'great device for the price. good looking screen quick and efficient. amazon app store isn´t that bad either', 'great for the price', datetime.date(2016, 12, 7), 1, 1, 175),
#  (180, '5', 'Great gift for any age. Wish I bought two. I can do everything on this that I was doing on my ipad', 'Perfect', datetime.date(2016, 12, 7), 1, 1, 176),
#  (181, '4', 'Great budget tablet for web browsing. Also useful as an MP3 player and ebook reader.', 'Best Bang For Your Money', datetime.date(2016, 12, 7), 1, 1, 177),
#  (182, '5', 'I got 2 of these for my 8 yr old twins. My 11 yr old has one but this one is better. Perfect way to get them to read', 'Xmas gift', datetime.date(2016, 12, 7), 1, 1, 178),
#  (183, '5', 'This is a superb tablet for the price. It doesn´t come with the Android operating system. It has Amazon´s operating system. The battery last a good long time and apps run very fast. I would recommend this to anyone who wants a tablet.', 'Great tablet at a great price', datetime.date(2016, 12, 7), 1, 1, 74),
#  (184, '5', 'My daughter love her new tablet I use for a few days and it´s pretty good', 'Great size', datetime.date(2016, 12, 7), 1, 1, 179),
#  (185, '5', 'So very happy with the new kindle ! I highly recommend this product !', 'So very happy with the new kindle !', datetime.date(2016, 12, 7), 1, 1, 180),
#  (186, '5', 'It may be cheap but this is a great tablet and works awesome.', 'Great tablet for the price', datetime.date(2016, 12, 7), 1, 1, 181),
#  (187, '5', 'My wife absolutely loves this tablet. It wad an early Christmas present', 'Tablet', datetime.date(2016, 12, 9), 1, 1, 182),
#  (188, '5', 'Bought for my 11 year old son and he absolutely loves it.', 'Great Kids Tablet', datetime.date(2016, 12, 9), 1, 1, 183),
#  (189, '5', 'I bought this as a Christmas gift for my son. Very easy to use.', 'Christmas Gift', datetime.date(2016, 12, 9), 1, 1, 184),
#  (190, '4', 'This product is very handy on the go. I can check emails and find work for my truck.', 'Great for on the go', datetime.date(2016, 12, 9), 1, 1, 185),
#  (191, '5', 'I am an Amazon Fan. Ive only had Amazon tablets so I cant compare them with any other brand. But Amazon has great customer service a lot of great app ... (198 characters truncated) ...  less expensive has a place for a sims card for extra space and has an ok front and rear facing camera. Overall its a great tablet for a great price.', 'Inexpensive yet Great quality tablet', datetime.date(2016, 12, 9), 1, 1, 186),
#  (192, '5', 'I previously had bought an older model of these tablets for my children. I wasn´t to happy with them. But this tablet is great it has child safety fe ... (136 characters truncated) ...  for what my kids will use it for which is mostly Netflix Hulu and even though there isn´t you tube app there are alternate apps that acces you tube.', 'Great tablet for children', datetime.date(2016, 12, 8), 1, 1, 187),
#  (193, '5', 'Got this tablet for Black Friday. Wow 16 gigs great screen expandable memory what a deal. Tablet is a must have for Amazon Prime members. It unlocks the door for all those great Prime perks; books shows and shopping. Pairs to Alexa. Great screen for books! Buy it already!', 'Great buy for Prime Members', datetime.date(2016, 12, 8), 1, 1, 188),
#  (194, '4', 'Bought it on black Friday for 60$ .Value for money tablet. It lags at heavy tasks and also apps are reloaded when 2-3 apps are opened at same time. But at this price it is expected. Go for it if budget is <100$.', 'Great budget tablet', datetime.date(2016, 12, 8), 1, 1, 189),
#  (195, '4', 'overall this is a good tablet. it is best with those who have Prime Amazon and the ability to watch Amazon video. a good price for a good tablet but has limitations based on the operating system. for video watching and basic use a good choice', 'good value', datetime.date(2016, 12, 23), 1, 1, 190),
#  (196, '5', 'I love the size and portability of this. Keeps me in touch and having fun.', 'Handy and fun.', datetime.date(2016, 12, 23), 1, 1, 191),
#  (197, '5', 'Nice tablet and couldn´t beat the Black Friday price', 'Great price', datetime.date(2016, 12, 23), 1, 1, 192),
#  (198, '5', 'I´m sorry I didn´t buy it sooner! Very easy to use. Love it.', 'fabulous!', datetime.date(2016, 12, 23), 1, 1, 193),
#  (199, '5', 'It feels a bit more rugged than my original Fire tablet and I believe it is an excellent value.', 'Excellent value', datetime.date(2016, 12, 23), 1, 1, 194),
#  (200, '4', 'Good tablet for basic needs. Screens resolution is pretty good. Mostly using for reading and sometimes for watching movies/shows. Great feature is the possibility to use the card to expand the memory. Good product for great price!', 'Good tablet for basic needs', datetime.date(2016, 12, 23), 1, 1, 195),
#  (201, '4', 'Bought as a gift for my 86 yr old mom to stalk her kids and grandkids on FB. She mastered it in a few.minutes with minimal instruction. Now I have to watch my posts.', 'Mom Loves it', datetime.date(2016, 12, 23), 1, 1, 196),
#  (202, '5', 'For a cheaper price this does more than my kindle- love having this tablet', 'should have purchased sooner', datetime.date(2016, 12, 23), 1, 1, 197),
#  (203, '5', 'Had a smaller version. Love the bigger screen. Use this product more than a computer.', 'Great product.', datetime.date(2016, 12, 27), 1, 1, 198),
#  (204, '5', 'I bought 2 of the kindles for my grandsons. They love them! Had them charged and set up right away. No issues at this point.', 'Great deal', datetime.date(2016, 12, 27), 1, 1, 199),
#  (205, '4', 'Easy to use bought for our 5 year old found a case which allows him to keep it safe.', 'Great tablet for my 5 year old to start with', datetime.date(2016, 12, 27), 1, 1, 200),
#  (206, '4', 'Great 8 inches tablet with and amazing storage for apps.', 'Awesome', datetime.date(2016, 12, 27), 1, 1, 201),
#  (207, '5', 'Santa dropped this off for our 4th grader along with expanded memory. he uses it for Netflix and Youtube as well as Minecraft and other Apps. Why spend hundreds on something for basic kids needs? I´m sure this will last him a few years and is well worth the price.', 'A great starter tablet for a youngster', datetime.date(2016, 12, 27), 1, 1, 202),
#  (208, '5', 'Got this tablet for my 3 year old son and he can not put it down. It is so much to do. So many learning games. I love this product', 'Great tablet', datetime.date(2016, 12, 26), 1, 1, 203),
#  (209, '4', 'This tablet runs smooth with all amazon apps the internet runs at a steady frame rate and it had a decent sized screen.', 'good for the price', datetime.date(2016, 12, 26), 1, 1, 204),
#  (210, '5', 'This is a good device for entertainment and entry level tasks. I think it can do a lot for the price.', 'Good overall tablet', datetime.date(2016, 12, 26), 1, 1, 205),
#  (211, '5', 'Nice price for the new model with Alexa built in and expandable storage!', 'It Has Alexa Built In!', datetime.date(2016, 12, 30), 1, 1, 206),
#  (212, '4', 'I have enjoyed the new Kindlehowever was extremely disappointed that it does not have an HDMI port like the old version did.', 'Same format as smartphone.', datetime.date(2016, 12, 30), 1, 1, 207),
#  (213, '4', 'this product is really awesome for kids to play in all sorts.We can use a strong case and let kids play in it .', 'worth having the product to kids', datetime.date(2016, 12, 30), 1, 1, 208),
#  (214, '4', 'i like the features it has and it is easy to navigate.', 'nice beginner tablet', datetime.date(2016, 12, 30), 1, 1, 209),
#  (215, '4', 'This is perfect my kids to do their school work on and have fun as well.', 'Perfect for my kids', datetime.date(2016, 12, 30), 1, 1, 210),
#  (216, '5', 'Great gift for my dad. Clear picture and easy set up', 'Gift for my dad.', datetime.date(2016, 12, 30), 1, 1, 211),
#  (217, '5', 'Love my kindle! Works better than expected! Kindle is much faster than my old tablet!', 'Love Kindle', datetime.date(2016, 12, 30), 1, 1, 212),
#  (218, '5', 'I have never owned a tablet. Wanted an I-Pad like most but couldn´t afford the sticker price. This one fit my needs perfect. I mainly just use it for web surfing and streaming video. No complaints so far! I would recommend this device.', 'Great starter tablet for someone like myself.', datetime.date(2016, 12, 30), 1, 1, 213),
#  (219, '5', 'also great for listening to music and also for movies', 'great for reading', datetime.date(2016, 12, 31), 1, 1, 214),
#  (220, '5', 'The screen picture is crisp and bright. I will use this tablet for many things.', 'Great tablet', datetime.date(2016, 12, 30), 1, 1, 215),
#  (221, '5', 'small and powerful... great adult toy for a reader', 'powerful', datetime.date(2016, 12, 30), 1, 1, 216),
#  (222, '5', 'This was purchased as a Christmas present for my aunt who lives with us. For the price I thought it would be a good option for her since she doesn´t  ... (680 characters truncated) ...  everything you need there.This is not a flagship device but performs incredibly for the price. I will most likely be purchasing one soon for myself.', 'Fantastic Tablet for the price', datetime.date(2016, 12, 30), 1, 1, 217),
#  (223, '3', 'I was hoping to use Google launcher with this tablet but it is really locked down and you cannot change the launcher or the lock screen. Still cheap and fine for watching movies.', 'A cheap tablet', datetime.date(2016, 12, 30), 0, 1, 218),
#  (224, '5', 'Great tablet for reading and also surfacing the web along with your favorite social media apps!', 'Great tablet!', datetime.date(2016, 12, 30), 1, 1, 219),
#  (225, '4', 'The price is low because Amazon uses their adds to subsidize the price. The actual tablet works well. The biggest negative is that you can only insta ... (151 characters truncated) ...  tablet for bible gateway dish anywhere play some games read the newspaper and Facebook. In the future I want to try to use it with my local library.', 'Price is great but limited to Amazon Apps', datetime.date(2016, 12, 30), 1, 1, 27),
# ...
#  (575, '4', 'If you don´t want or need something cheaper than an iPad but of quality this is a great happy medium.The processor makes for a fluid ride with it. It ... (99 characters truncated) ... .The software is a touch buggy but it´s still a great deal of a tablet.For a child for something you want to use casually on a dime it´s recommended.', 'Bang for the buck . . .', datetime.date(2016, 10, 29), 1, 1, 554),
#  (576, '5', 'Easy to read. Light in weight. Has many good features.', 'Great tablet', datetime.date(2016, 10, 29), 1, 1, 209),
#  (577, '5', 'I read about this new 8 Amazon tablet in the New York Times. My Google Nexus 7 4 years old was getting slower and slower and I needed to upgrade - fo ... (442 characters truncated) ... d one! Congrats to Amazon for making an affordable great quality tablet!Also the purchasing experience at Best Buy was easy and convenient as always!', 'A Lot of Bang for the Buck!', datetime.date(2016, 10, 29), 1, 1, 555),
#  (578, '5', 'The new Fire HD 8 is an improvement over the Fire HD 7. It is faster and the larger screen makes reading books much easier. I do wish the screen was easier to read when outside or in the car. Too much glare in those places.', 'Great Replacement for my Kindle Fire HD 7', datetime.date(2016, 10, 29), 1, 1, 556),
#  (579, '5', 'Love it! I´m not computer savy but was able to figure out most things without any help.', 'Needs manual for basic functions.', datetime.date(2016, 10, 28), 1, 1, 557),
#  (580, '5', 'Mother needed something since her tablet had died. Was lot easier for her to learn than her old table. She does lots more with Kindle than she did with tablet', 'Replace a tablet', datetime.date(2016, 11, 4), 1, 1, 558),
#  (581, '4', 'Light to carry and good picture quality. This was purchased for a hearing impaired person to download video in American Sign Language . This product was easy to maneuver for someone that was not use to a tablet.', 'Great for hearing impaired in downloading videos', datetime.date(2016, 11, 4), 1, 1, 559),
#  (582, '4', 'I love this tablet. I purchased them for gift and am so glad I did!', 'PERFECT!', datetime.date(2016, 11, 4), 1, 1, 560),
#  (583, '5', 'I am still learning all the things I can do with my new Kindle Fire. It is so much better lighter in weight and easier to use than my old tablet.', 'Enjoying my new tablet', datetime.date(2017, 2, 3), 1, 1, 34),
#  (584, '5', 'Excellent tablet to leave at my easel and display reference photos. It´s light enough to velcro to a articulating stand so I can position the tablet right next to my canvas. It´s cheap enough to not worry about. I love it for the price.', 'Perfect for artist reference photos!', datetime.date(2017, 6, 3), 1, 1, 61),
#  (585, '5', 'Was looking for a tablet that was highly portable & could run my DIRECTTV app & stream videos. Other electronics I have are much older versions. Sale ... (19 characters truncated) ... is model to me based on personal experience. I am still learning all its functions but so far it seems easy to use & is doing what it promised to do.', 'First Amazon FIRE', datetime.date(2017, 5, 8), 1, 1, 86),
#  (586, '5', 'Thanks to a knowledgeable low-pressure salesperson I was ready to buy my first tablet. This one was the right price on sale and I have not been disap ... (114 characters truncated) ... books. It stays charged for days even with regular use. I recommend it as an inexpensive and very satisfactory alternative to more expensive tablets.', 'Easy to learn to use its many features.', datetime.date(2017, 5, 7), 1, 1, 89),
#  (587, '5', 'We love the FreeTime settings for kids on the newer Kindle Fires. I was able to create a login for each of our kids as well as myself and set limits  ... (486 characters truncated) ... to continually monitor every moment. By the way FreeTime kids settings are available without having to subscribe to their FreeTime app access plan. :', 'Great tablet for kids!', datetime.date(2017, 1, 6), 1, 1, 93),
#  (588, '5', 'Purchased as a door prize gift given with a one year Amazon membership. The recipient loves it and says it performs very well. As a past Amazon Fire  ... (7 characters truncated) ... w i-Pad graduate I loved my Amazon Fire for more than 4 years without any problems. In fact I just recycled it on to my son and it runs like a champ.', 'Excellent -- purchased for door prize', datetime.date(2017, 1, 6), 1, 1, 98),
#  (589, '5', 'I am a prime member & I love this tablet. Very user friendly especially if you are a prime member with amazon. Not real tech savvy so I need all the  ... (199 characters truncated) ... f 10. Also easier to take around in the smaller size. Highly recommend especially if you subscribe to Amazon and are a prime member. Great benefits!!', 'Love this tablet!', datetime.date(2017, 1, 7), 1, 1, 112),
#  (590, '1', 'i Bought this around black friday for $60 hoping it would be awesome... it failed so hard i tried multiple different micro SD cards none of which wer ... (777 characters truncated) ... pay for... also hint the s-pen version has an extra 1 GB of ram over the non pen version... so you should get that if you can afford the extra $50...', 'TERRIBLE DONT BUY', datetime.date(2017, 1, 10), 0, 1, 126),
#  (591, '5', 'The latest Amazon 8 HD tablet is a very good tablet for the price. The updated processor and extra memory with expansion slot allow for very good per ... (39 characters truncated) ...  for. Netflix Hulu browsing the internet and doing e-mails all work very smoothly. Would recommend to anyone looking for a very cost effective tablet', 'Amazon 8 HD Tablet', datetime.date(2017, 1, 23), 1, 1, 135),
#  (592, '4', 'Bought one to replace the smaller non HD version. Lot faster and picture is noticeably better. Would recommend for anyone not wanting to spend the extra $50 or so on the big names.', 'Good bargain tablet', datetime.date(2017, 3, 19), 1, 1, 238),
#  (593, '4', 'I bought this tablet to be pretty much exclusively an e-reader. It´s actually cheaper than most of the kindles. For that limited use it works fine. I ... (48 characters truncated) ...  purpose table too slow!. Makes a fine e-reader though. As for recommending this to a friend I would but would make sure they knew what I use it for.', 'Good for what I use it for', datetime.date(2017, 3, 20), 1, 1, 249),
#  (594, '4', 'Ticks all the boxes I was looking for at a price I was happy to pay. One caveat that I or the Best Buy and Geek Squad crews was unaware of: there is  ... (155 characters truncated) ... ace the keyboard that´s built in to the unit until they are able to fix the problem. I made Geek Squad aware of it and they should know about it now.', 'Excellent for the money', datetime.date(2017, 3, 25), 1, 1, 253),
#  (595, '5', 'I bought this after subscribing to an Amazon Prime membership. This is a great little tablet at such a low price.. too good of a deal to pass up when ... (5 characters truncated) ... as on sale. It has the ability to talk to Alexa surf the web listen to music and read books/magazines lots of free music and books for Prime members.', 'Too good to pass up!', datetime.date(2017, 2, 23), 1, 1, 327),
#  (596, '5', 'Bought this 8 model to use in addition to my current 3 year old Kindle Fire HD 7 inch model. So far I am very pleased with the quality of this unit. The slightly larger screen makes watching movies much better. I didn´t want the larger 10 screen yet.', 'Great tablet', datetime.date(2017, 2, 21), 1, 1, 333),
#  (597, '5', 'I bought this for my son he´s 1.5 years old so he could play basic toddler games but I found the tablet to be extremely useful for school with it´s l ... (101 characters truncated) ...  for so cheap is making me second guess paying so much! For basic lecture taking notes and watching Netflix or Hulu and kid games this can´t be beat.', 'Outstanding value!', datetime.date(2017, 1, 4), 1, 1, 335),
#  (598, '5', 'My original Kindle Fire no longer accepted a charge. I wasn´t going to replace it because I bought an iPad. When I saw the HD8 in a kiosk in a BB sto ... (246 characters truncated) ...  locked screen - that it HAS to be an advertisement. I also don´t like that it usually takes a few trys to unlock. Menial issues from my perspective.', 'It fits my need perfectly', datetime.date(2017, 3, 27), 1, 1, 394),
#  (599, '4', 'The Parental Options need some work. You can´t even log in to a child account until you have Apps loaded for them to use. Also a kid´s login doesn´t  ... (35 characters truncated) ...  the calculator. Seems really odd to me that you can´t give them access to basic functionality of the tablet.Otherwise the tablet itself works great.', 'Works well but Needs Better Parental Options', datetime.date(2016, 12, 23), 1, 1, 418),
#  (600, '5', 'I´m loving the tablet so far. I really like the Amazon underground and the Fire OS just updated so it has Alexa on it now. :', 'So far so good', datetime.date(2016, 11, 21), 1, 1, 465),
#  (601, '3', 'I had fire hdx 8 and loved it unfortunately got damaged and could not replace. I purchased the fire HD 8 and exchanged n pay difference for fire HD 10. The 8 did not have a lot of options I was used to. :', 'Ok for a young person', datetime.date(2016, 11, 12), 0, 1, 518),
#  (602, '3', 'The Amazon Fire HD8 2016 model is a great tablet for the price; however the Fire OS offers limited abilities to the user. Personally I wish there wer ... (77 characters truncated) ... aming stick. Also the inability to use the google play store is a major set back. If it weren´t for those two complaint I´d give this tablet 4 stars.', 'Great tablet for the price', datetime.date(2016, 11, 11), 1, 1, 524),
#  (603, '4', 'Works well. I really like the bigger screen up from the 7. Easier to read just as easier to use if not better.', 'Love of games', datetime.date(2016, 11, 7), 1, 1, 533),
#  (604, '4', 'Great inexpensive tablet for everyday use. It´s not powerful enough for super graphical games but it´s great for basic apps like surfing the web emai ... (150 characters truncated) ... creen ads in them usually products that´s on your Amazon wishlist. All-in-all it´s a great tablet that you don´t have to worry about if you break it.', 'Great Tablet', datetime.date(2016, 11, 5), 1, 1, 540),
#  (605, '5', 'I read about this new 8 Amazon tablet in the New York Times. My Google Nexus 7 4 years old was getting slower and slower and I needed to upgrade - fo ... (440 characters truncated) ... d one! Congrats to Amazon for making an affordable great quality tablet!Also the purchasing experience at Best Buy was easy and convenient as always!', 'A Lot of Bang for the Buck!', datetime.date(2016, 10, 29), 1, 1, 555),
#  (606, '5', 'i have had not issues with my purchase. i found a great cover for it on line on amazon and use it every night. thank you for your service.', 'great product and service', datetime.date(2016, 11, 4), 1, 1, 562),
#  (607, '5', 'This has a great picture good size lots of storage and a camera. Would recommend', 'Has everything you need', datetime.date(2016, 11, 4), 1, 1, 563),
#  (608, '5', 'I went from the 7 inch Kindle to the 8 and it really made a difference. Easier to read and clearer than my old one.', 'Needed the bigger tablet.', datetime.date(2016, 10, 28), 1, 1, 564),
#  (609, '5', 'I love this Tablet. It´s easy to use a great price & lightweight.', 'great for the price', datetime.date(2016, 10, 28), 1, 1, 565),
#  (610, '5', 'This is my second Kindle Fire HD. I was satisfied with the first one but now I´m really enjoying the larger screen. My biggest need is to preserve the progress I´ve made in various games without having to replay them but at least I have access to all my books movies and games. Love the Kindle!', 'Love the Kindle Fire HD', datetime.date(2016, 10, 28), 1, 1, 566),
#  (611, '5', 'Love the product. I use it every day for WebGames and reading.', 'Works great', datetime.date(2016, 10, 28), 1, 1, 567),
#  (612, '5', 'I bought this to replace my wife´s 1st generation Kindle Fire. She likes it even better than the old one especially the pinsharp screen.', 'Even better than before', datetime.date(2016, 10, 28), 1, 1, 568),
#  (613, '5', 'Great Kindle fire works great for reading playing games etc. Highly recommend to everyone.', 'Great Kindle Fire', datetime.date(2016, 10, 28), 1, 1, 569),
#  (614, '4', 'Very pleased with this device. Great price easy to use and light weight.', 'Great buy', datetime.date(2016, 10, 28), 1, 1, 570),
#  (615, '5', 'Nice upgrade from my old kindle. I like it very much.', 'great product', datetime.date(2016, 10, 28), 1, 1, 571),
#  (616, '5', 'For the price this is perfect. I read books search the web watch Netflix. It´s not an iPad but for the price it is amazing!', 'Perfect', datetime.date(2016, 10, 28), 1, 1, 572),
#  (617, '5', 'İt is cheap tablet option coming from amazon. Latest model will satisfy your needs', 'CHEAP OPTİON', datetime.date(2016, 10, 25), 1, 1, 573),
#  (618, '4', 'Very descent for a non-IPAD. Good speakers. Great price. The screen is a little dark. Great buy if you have Amazon Prime since you can download stuff and watch it offline great for trips etc.... Overall great cheap IPAD or even as a back-up tablet. Terrific battery life too.', 'Very descent', datetime.date(2016, 10, 25), 1, 1, 512),
#  (619, '5', 'This thing looks nice runs nice and feels nice and for the price I don´t think you can find a better tablet.', 'Can´t beat it!', datetime.date(2016, 10, 24), 1, 1, 574),
#  (620, '4', 'Got this for my 9 year old after her ipad crashed and burned. She does not like androids at all but I couldn´t afford a expensive tablet for her. So  ... (14 characters truncated) ... ce with this one. She is pleased and I´m pleased it seems so sturdy  not cheap quality at all. Going to get our youngest child one now. Very pleased.', 'Really great for the price!', datetime.date(2016, 10, 23), 1, 1, 575),
#  (621, '5', 'The quality of display is better than expected for the price. Keep in mind that this is not an iPad!. Apps from amazon are well integrated and the functionality is fully enjoyable without limitation. Very satisfied with the product. This review is for Fire HD 8 16 GB.', 'Best tablet backed by Amazon', datetime.date(2016, 10, 22), 1, 1, 576),
#  (622, '4', 'I like it but I had a hard time figuring things out.Do I get to talk to geek squad free? Can I come down to the store and get someone to help me with my questions.Will there be a fee for that service?', 'like product need some help w/questions', datetime.date(2016, 10, 21), 1, 1, 577),
#  (623, '5', 'Beautiful HD resolution on this tablet. Love the 8 size not too big nor too small.', 'Great 8 tablet!!', datetime.date(2016, 10, 21), 1, 1, 578),
#  (624, '5', 'This is an awesome tablet fast great display and has all the apps I need for personal entertainment If you look for a great tablet for entertainment  ... (195 characters truncated) ... and internal memory and the external memory to keep all your photos is unbelievable I strongly recommend it again not for work but for entertainment.', 'Excellent Tablet for Entertaiment', datetime.date(2016, 10, 21), 1, 1, 579),
#  (625, '5', 'I bought 2 1 for each kid. Easy to set up and figure iut. I went with the staff member´s recommendation and I am so glad I did. I love the internet s ... (93 characters truncated) ... afe Internet access and movies books games and apps and I can set the time it shuts off and a minimum time for them to read each day. Love love love.', 'Best buy for the kids ever!', datetime.date(2016, 10, 21), 1, 1, 580),
#  (626, '4', 'Good tablet great price easy to use pick up simple', 'Good tablet', datetime.date(2016, 10, 21), 1, 1, 239),
#  (627, '5', 'Very happy with my kindle. Would buy it for my kids', 'Love my kindle', datetime.date(2016, 10, 20), 1, 1, 581)]

# %% [markdown]
# ## 3. Definimos funciones para introducir ratings, users y productos en la BD en SQL.

# %% [markdown]
# ***Sería bueno intentar cargamos estas funciones desde un archivo functions_dani.py. Tengo que preguntarlo. me da error de que el engine no está definido.***

# %%
#from src import functions_dani as fdani

# %%
#fdani.check("username","dadasd")

# %%
def check(que,string):
    """
    Función parametrizada que comprueba en cada tabla si existe el user, producto o rating.
    Si existe, devuelve una lista con True y el ID dentro de la tabla
    Si no exite, devuelve una lista con False y None.
    """
    if que == "username":
        query = list(engine.execute(f"SELECT username FROM user_names WHERE username = '{string}'"))
        if len(query) > 0:
            return [True,list(engine.execute(f"SELECT ID FROM user_names WHERE username ='{string}';"))[0][0]]
        else:
            return [False,None]
        
    elif que == "product":
        query = list(engine.execute(f"SELECT productname FROM product_names WHERE productname = '{string}'"))
        if len(query) > 0:
            return [True,list(engine.execute(f"SELECT ID FROM product_names WHERE productname = '{string}'"))[0][0]]
        else:
            return [False,None]
        
    elif que == "rating":
        query = list(engine.execute(f"SELECT texto FROM ratings WHERE texto = '{string}'"))
        if len(query) > 0:
            return [True,list(engine.execute(f"SELECT ID FROM ratings WHERE texto = '{string}'"))[0][0]]
        else:
            return [False,None]

# %%
def insert_user(string):
    """
    
    Primero se comprueba si ya existe el usuario.
    Si no existe se introduce.
    En ambos casos la función informa por pantalla de lo que hace y devuelve el ID del usuario
    """
    exists,ID = check("username", string)
    if exists:
        #print(f"Ya existe el usuario: '{string}' y tiene el ID {ID}")
        pass
    else:
        engine.execute(f"INSERT INTO user_names (username) VALUES ('{string}');")
        exists,ID = check("username", string)
        #print(f"Nuevo usuario insertado en BBDD: '{string}' y se le ha asignado el ID {ID}")
    
    return ID

# %%
def insert_product(string):
    """
    Primero comprobamos si ya existe el producto.
    Si no existe se introduce.
    En ambos casos la función informa por pantalla de lo que hace y devuelve el ID del producto
    """
    exists,ID = check("product", string)
    if exists:
        #print(f"Ya existe el producto: '{string[:25]}...' y tiene el ID {ID}")
        pass
    else:
        engine.execute(f"INSERT INTO product_names (productname) VALUES ('{string}');")
        exists,ID = check("product", string)
        print(f"Nuevo producto insertado en BBDD: '{string[:25]}...' y se le ha asignado el ID {ID}")
    
    return ID

# %%
def insert_rating(fila):
    """
    Esta función mete los comentarios que se le pasan fila por fila de un dataframe en la BBDD SQL.
    Primero llama a la función insert_user con el username del rating incluido en la "fila"
    Segungo llama a la función insert_product con el product del rating incluido en la "fila"
    Tercero comprueba si existe el rating en dicha tabla
        Si ya existe, informa por pantalla y la función devuelve el ID del rating en BBDD de SQL
        Si no existe, lo introduce, informa por pantalla y devuelve el ID del rating en BBDD de SQL
    """
    mark          = int(fila["rating"])
    texto         = fila["rating_text"]
    title         = fila["rating_title"]
    date_         = fila["date"]
    recommended   = int(fila["recommended"])
    ID_p          = insert_product(fila["Product_name"])
    ID_u          = insert_user(fila["username"])

    exists_r,ID_r = check("rating", texto )
            
    if exists_r:
        #print(f"Ya existe el rating '{texto[:20]}...' y tiene el ID {ID_r}")
        pass
    else:
        engine.execute(f"""
        INSERT INTO ratings (mark, texto, title, date_, recommended, ID_product, ID_user) 
        VALUES ({mark},'{texto}','{title}','{date_}','{recommended}','{ID_p}','{ID_u}');
        """)
        exits_r,ID_r = check("rating", texto )
        #print(f"Nuevo rating insertado en BBDD: '{texto[:20]}...' y tiene el ID {ID_r}")
    
    return ID_r

# %% [markdown]
# ## 4. Cargamos el CSV ya limpio

# %%
ars = pd.read_csv("../data/amazon_reviews_clean.csv")

# %%
ars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27406 entries, 0 to 27405
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_name  27406 non-null  object
#  1   rating        27406 non-null  float64
#  2   rating_text   27406 non-null  object
#  3   rating_title  27406 non-null  object
#  4   recommended   27406 non-null  bool
#  5   username      27406 non-null  object
#  6   date          27406 non-null  object
#  7   year          27406 non-null  int64
#  8   month         27406 non-null  int64
#  9   day           27406 non-null  int64
# dtypes: bool(1), float64(1), int64(3), object(5)
# memory usage: 1.9+ MB

# %%
ars.head()
# Out:
#                                         Product_name  rating  \
# 0  All-New Fire HD 8 Tablet 8 HD Display Wi-Fi 16...     5.0
# 1  All-New Fire HD 8 Tablet 8 HD Display Wi-Fi 16...     5.0
# 2  All-New Fire HD 8 Tablet 8 HD Display Wi-Fi 16...     5.0
# 3  All-New Fire HD 8 Tablet 8 HD Display Wi-Fi 16...     4.0
# 4  All-New Fire HD 8 Tablet 8 HD Display Wi-Fi 16...     5.0
#
#                                          rating_text  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I´ve had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                               rating_title  recommended   username  \
# 0                                   Kindle         True    Adapter
# 1                                very fast         True     truman
# 2  Beginner tablet for our 9 year old son.         True      DaveZ
# 3                                  Good!!!         True     Shacks
# 4                Fantastic Tablet for kids         True  explore42
#
#          date  year  month  day
# 0  2017-01-13  2017      1   13
# 1  2017-01-13  2017      1   13
# 2  2017-01-13  2017      1   13
# 3  2017-01-13  2017      1   13
# 4  2017-01-12  2017      1   12

# %% [markdown]
# ## 5. Iteramos fila por fila en todo el dataframe y para meter todas las filas en la BBDD

# %%
ratings_que_dan_error = []
for index,fila in ars.iterrows() :
    #print(index)
    if index%100 == 0:
        print(f"Se han cargado ya {index} de un total de {len(ars)}")
    try: 
        insert_rating(fila);
    except Exception as err:
        print(f"Row {index} da error. Se registra.     --> {type(err).__name__} : {err}")
        ratings_que_dan_error.append( {"row" : index , "error_type" : type(err).__name__ , "error_message" : err.args } )
# Out:
# Se han cargado ya 0 de un total de 27406
# Se han cargado ya 100 de un total de 27406
# Se han cargado ya 200 de un total de 27406
# Se han cargado ya 300 de un total de 27406
# Se han cargado ya 400 de un total de 27406
# Se han cargado ya 500 de un total de 27406
# Row 581 da error. Se registra.     --> ValueError : unsupported format character 't' (0x74) at index 165
# Se han cargado ya 600 de un total de 27406
# Row 606 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 700 de un total de 27406
# Row 727 da error. Se registra.     --> ValueError : unsupported format character 'b' (0x62) at index 1273
# Se han cargado ya 800 de un total de 27406
# Se han cargado ya 900 de un total de 27406
# Se han cargado ya 1000 de un total de 27406
# Se han cargado ya 1100 de un total de 27406
# Se han cargado ya 1200 de un total de 27406
# Se han cargado ya 1300 de un total de 27406
# Row 1323 da error. Se registra.     --> ValueError : unsupported format character 't' (0x74) at index 335
# Se han cargado ya 1400 de un total de 27406
# Se han cargado ya 1500 de un total de 27406
# Row 1548 da error. Se registra.     --> ValueError : unsupported format character 'b' (0x62) at index 191
# Se han cargado ya 1600 de un total de 27406
# Row 1632 da error. Se registra.     --> ValueError : unsupported format character ' ' (0x20) at index 211
# Se han cargado ya 1700 de un total de 27406
# Se han cargado ya 1800 de un total de 27406
# Se han cargado ya 1900 de un total de 27406
# Se han cargado ya 2000 de un total de 27406
# Se han cargado ya 2100 de un total de 27406
# Se han cargado ya 2200 de un total de 27406
# Row 2258 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 2300 de un total de 27406
# Se han cargado ya 2400 de un total de 27406
# Se han cargado ya 2500 de un total de 27406
# Se han cargado ya 2600 de un total de 27406
# Row 2643 da error. Se registra.     --> ValueError : unsupported format character ' ' (0x20) at index 237
# Row 2659 da error. Se registra.     --> ValueError : unsupported format character ' ' (0x20) at index 337
# Se han cargado ya 2700 de un total de 27406
# Se han cargado ya 2800 de un total de 27406
# Row 2870 da error. Se registra.     --> ValueError : unsupported format character 'b' (0x62) at index 2762
# Se han cargado ya 2900 de un total de 27406
# Se han cargado ya 3000 de un total de 27406
# Se han cargado ya 3100 de un total de 27406
# Se han cargado ya 3200 de un total de 27406
# Se han cargado ya 3300 de un total de 27406
# Se han cargado ya 3400 de un total de 27406
# Se han cargado ya 3500 de un total de 27406
# Se han cargado ya 3600 de un total de 27406
# Se han cargado ya 3700 de un total de 27406
# Se han cargado ya 3800 de un total de 27406
# Se han cargado ya 3900 de un total de 27406
# Se han cargado ya 4000 de un total de 27406
# Row 4012 da error. Se registra.     --> ValueError : unsupported format character 'S' (0x53) at index 111
# Se han cargado ya 4100 de un total de 27406
# Se han cargado ya 4200 de un total de 27406
# Se han cargado ya 4300 de un total de 27406
# Row 4301 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 4400 de un total de 27406
# Se han cargado ya 4500 de un total de 27406
# Se han cargado ya 4600 de un total de 27406
# Se han cargado ya 4700 de un total de 27406
# Se han cargado ya 4800 de un total de 27406
# Se han cargado ya 4900 de un total de 27406
# Se han cargado ya 5000 de un total de 27406
# Se han cargado ya 5100 de un total de 27406
# Se han cargado ya 5200 de un total de 27406
# Row 5249 da error. Se registra.     --> TypeError : must be real number, not dict
# Se han cargado ya 5300 de un total de 27406
# Se han cargado ya 5400 de un total de 27406
# Se han cargado ya 5500 de un total de 27406
# Row 5598 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 5600 de un total de 27406
# Se han cargado ya 5700 de un total de 27406
# Se han cargado ya 5800 de un total de 27406
# Se han cargado ya 5900 de un total de 27406
# Se han cargado ya 6000 de un total de 27406
# Se han cargado ya 6100 de un total de 27406
# Se han cargado ya 6200 de un total de 27406
# Se han cargado ya 6300 de un total de 27406
# Se han cargado ya 6400 de un total de 27406
# Se han cargado ya 6500 de un total de 27406
# Se han cargado ya 6600 de un total de 27406
# Se han cargado ya 6700 de un total de 27406
# Se han cargado ya 6800 de un total de 27406
# Row 6815 da error. Se registra.     --> TypeError : not enough arguments for format string
# Se han cargado ya 6900 de un total de 27406
# Se han cargado ya 7000 de un total de 27406
# Se han cargado ya 7100 de un total de 27406
# Se han cargado ya 7200 de un total de 27406
# Se han cargado ya 7300 de un total de 27406
# Se han cargado ya 7400 de un total de 27406
# Row 7461 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 7500 de un total de 27406
# Se han cargado ya 7600 de un total de 27406
# Row 7643 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 7700 de un total de 27406
# Se han cargado ya 7800 de un total de 27406
# Se han cargado ya 7900 de un total de 27406
# Se han cargado ya 8000 de un total de 27406
# Se han cargado ya 8100 de un total de 27406
# Se han cargado ya 8200 de un total de 27406
# Se han cargado ya 8300 de un total de 27406
# Se han cargado ya 8400 de un total de 27406
# Se han cargado ya 8500 de un total de 27406
# Se han cargado ya 8600 de un total de 27406
# Se han cargado ya 8700 de un total de 27406
# Se han cargado ya 8800 de un total de 27406
# Se han cargado ya 8900 de un total de 27406
# Se han cargado ya 9000 de un total de 27406
# Row 9015 da error. Se registra.     --> TypeError : must be real number, not dict
# Se han cargado ya 9100 de un total de 27406
# Se han cargado ya 9200 de un total de 27406
# Row 9239 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 9300 de un total de 27406
# Se han cargado ya 9400 de un total de 27406
# Se han cargado ya 9500 de un total de 27406
# Row 9587 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 9600 de un total de 27406
# Se han cargado ya 9700 de un total de 27406
# Se han cargado ya 9800 de un total de 27406
# Row 9822 da error. Se registra.     --> ValueError : unsupported format character ')' (0x29) at index 1236
# Se han cargado ya 9900 de un total de 27406
# Se han cargado ya 10000 de un total de 27406
# Se han cargado ya 10100 de un total de 27406
# Se han cargado ya 10200 de un total de 27406
# Se han cargado ya 10300 de un total de 27406
# Se han cargado ya 10400 de un total de 27406
# Se han cargado ya 10500 de un total de 27406
# Se han cargado ya 10600 de un total de 27406
# Row 10685 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 10700 de un total de 27406
# Se han cargado ya 10800 de un total de 27406
# Se han cargado ya 10900 de un total de 27406
# Se han cargado ya 11000 de un total de 27406
# Se han cargado ya 11100 de un total de 27406
# Se han cargado ya 11200 de un total de 27406
# Row 11212 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 11300 de un total de 27406
# Se han cargado ya 11400 de un total de 27406
# Se han cargado ya 11500 de un total de 27406
# Se han cargado ya 11600 de un total de 27406
# Se han cargado ya 11700 de un total de 27406
# Se han cargado ya 11800 de un total de 27406
# Se han cargado ya 11900 de un total de 27406
# Se han cargado ya 12000 de un total de 27406
# Se han cargado ya 12100 de un total de 27406
# Se han cargado ya 12200 de un total de 27406
# Se han cargado ya 12300 de un total de 27406
# Se han cargado ya 12400 de un total de 27406
# Se han cargado ya 12500 de un total de 27406
# Se han cargado ya 12600 de un total de 27406
# Se han cargado ya 12700 de un total de 27406
# Se han cargado ya 12800 de un total de 27406
# Se han cargado ya 12900 de un total de 27406
# Se han cargado ya 13000 de un total de 27406
# Se han cargado ya 13100 de un total de 27406
# Se han cargado ya 13200 de un total de 27406
# Se han cargado ya 13300 de un total de 27406
# Se han cargado ya 13400 de un total de 27406
# Row 13495 da error. Se registra.     --> ValueError : unsupported format character ' ' (0x20) at index 65
# Se han cargado ya 13500 de un total de 27406
# Se han cargado ya 13600 de un total de 27406
# Se han cargado ya 13700 de un total de 27406
# Se han cargado ya 13800 de un total de 27406
# Se han cargado ya 13900 de un total de 27406
# Se han cargado ya 14000 de un total de 27406
# Nuevo producto insertado en BBDD: 'Kindle Oasis E-reader wit...' y se le ha asignado el ID 8
# Nuevo producto insertado en BBDD: 'Amazon - Kindle Voyage - ...' y se le ha asignado el ID 9
# Nuevo producto insertado en BBDD: 'Fire HD 8 Tablet with Ale...' y se le ha asignado el ID 10
# Nuevo producto insertado en BBDD: 'Amazon Standing Protectiv...' y se le ha asignado el ID 11
# Nuevo producto insertado en BBDD: 'Certified Refurbished Ama...' y se le ha asignado el ID 12
# Nuevo producto insertado en BBDD: 'Brand New Amazon Kindle F...' y se le ha asignado el ID 13
# Se han cargado ya 14100 de un total de 27406
# Se han cargado ya 14200 de un total de 27406
# Se han cargado ya 14300 de un total de 27406
# Se han cargado ya 14400 de un total de 27406
# Se han cargado ya 14500 de un total de 27406
# Row 14523 da error. Se registra.     --> ValueError : unsupported format character 'y' (0x79) at index 222
# Se han cargado ya 14600 de un total de 27406
# Se han cargado ya 14700 de un total de 27406
# Se han cargado ya 14800 de un total de 27406
# Se han cargado ya 14900 de un total de 27406
# Se han cargado ya 15000 de un total de 27406
# Nuevo producto insertado en BBDD: 'Amazon Kindle Touch Leath...' y se le ha asignado el ID 14
# Nuevo producto insertado en BBDD: 'Fire Kids Edition Tablet ...' y se le ha asignado el ID 15
# Se han cargado ya 15100 de un total de 27406
# Se han cargado ya 15200 de un total de 27406
# Row 15299 da error. Se registra.     --> ValueError : unsupported format character 'K' (0x4b) at index 672
# Se han cargado ya 15300 de un total de 27406
# Se han cargado ya 15400 de un total de 27406
# Se han cargado ya 15500 de un total de 27406
# Se han cargado ya 15600 de un total de 27406
# Se han cargado ya 15700 de un total de 27406
# Se han cargado ya 15800 de un total de 27406
# Row 15858 da error. Se registra.     --> ValueError : unsupported format character ' ' (0x20) at index 490
# Se han cargado ya 15900 de un total de 27406
# Se han cargado ya 16000 de un total de 27406
# Se han cargado ya 16100 de un total de 27406
# Se han cargado ya 16200 de un total de 27406
# Se han cargado ya 16300 de un total de 27406
# Se han cargado ya 16400 de un total de 27406
# Se han cargado ya 16500 de un total de 27406
# Se han cargado ya 16600 de un total de 27406
# Se han cargado ya 16700 de un total de 27406
# Nuevo producto insertado en BBDD: 'Amazon Kindle Paperwhite ...' y se le ha asignado el ID 16
# Se han cargado ya 16800 de un total de 27406
# Se han cargado ya 16900 de un total de 27406
# Se han cargado ya 17000 de un total de 27406
# Se han cargado ya 17100 de un total de 27406
# Se han cargado ya 17200 de un total de 27406
# Se han cargado ya 17300 de un total de 27406
# Row 17323 da error. Se registra.     --> ValueError : unsupported format character ' ' (0x20) at index 124
# Se han cargado ya 17400 de un total de 27406
# Se han cargado ya 17500 de un total de 27406
# Se han cargado ya 17600 de un total de 27406
# Se han cargado ya 17700 de un total de 27406
# Se han cargado ya 17800 de un total de 27406
# Row 17863 da error. Se registra.     --> ValueError : unsupported format character 'm' (0x6d) at index 106
# Se han cargado ya 17900 de un total de 27406
# Se han cargado ya 18000 de un total de 27406
# Se han cargado ya 18100 de un total de 27406
# Se han cargado ya 18200 de un total de 27406
# Row 18200 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 18300 de un total de 27406
# Se han cargado ya 18400 de un total de 27406
# Row 18465 da error. Se registra.     --> ValueError : unsupported format character '!' (0x21) at index 459
# Se han cargado ya 18500 de un total de 27406
# Se han cargado ya 18600 de un total de 27406
# Se han cargado ya 18700 de un total de 27406
# Se han cargado ya 18800 de un total de 27406
# Row 18891 da error. Se registra.     --> ValueError : unsupported format character 'b' (0x62) at index 141
# Se han cargado ya 18900 de un total de 27406
# Se han cargado ya 19000 de un total de 27406
# Se han cargado ya 19100 de un total de 27406
# Se han cargado ya 19200 de un total de 27406
# Se han cargado ya 19300 de un total de 27406
# Se han cargado ya 19400 de un total de 27406
# Se han cargado ya 19500 de un total de 27406
# Se han cargado ya 19600 de un total de 27406
# Row 19654 da error. Se registra.     --> TypeError : %c requires int or char
# Se han cargado ya 19700 de un total de 27406
# Se han cargado ya 19800 de un total de 27406
# Row 19840 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 19900 de un total de 27406
# Nuevo producto insertado en BBDD: 'Kindle Voyage E-reader 6 ...' y se le ha asignado el ID 17
# Se han cargado ya 20000 de un total de 27406
# Se han cargado ya 20100 de un total de 27406
# Row 20192 da error. Se registra.     --> ValueError : unsupported format character 'b' (0x62) at index 374
# Se han cargado ya 20200 de un total de 27406
# Se han cargado ya 20300 de un total de 27406
# Se han cargado ya 20400 de un total de 27406
# Se han cargado ya 20500 de un total de 27406
# Nuevo producto insertado en BBDD: 'Certified Refurbished Ama...' y se le ha asignado el ID 18
# Nuevo producto insertado en BBDD: 'Kindle Paperwhite...' y se le ha asignado el ID 19
# Nuevo producto insertado en BBDD: 'Amazon Fire Kids Edition ...' y se le ha asignado el ID 20
# Nuevo producto insertado en BBDD: 'Kindle Paperwhite E-reade...' y se le ha asignado el ID 21
# Row 20566 da error. Se registra.     --> ValueError : unsupported format character 'b' (0x62) at index 443
# Nuevo producto insertado en BBDD: 'Amazon Echo and Fire TV P...' y se le ha asignado el ID 22
# Nuevo producto insertado en BBDD: 'Amazon Fire Hd 8 8in Tabl...' y se le ha asignado el ID 23
# Se han cargado ya 20600 de un total de 27406
# Row 20651 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Row 20685 da error. Se registra.     --> TypeError : must be real number, not dict
# Se han cargado ya 20700 de un total de 27406
# Nuevo producto insertado en BBDD: 'Certified Refurbished Ama...' y se le ha asignado el ID 24
# Nuevo producto insertado en BBDD: 'Amazon - Fire 16GB (5th G...' y se le ha asignado el ID 25
# Nuevo producto insertado en BBDD: 'Fire Tablet 7 Display Wi-...' y se le ha asignado el ID 26
# Se han cargado ya 20800 de un total de 27406
# Se han cargado ya 20900 de un total de 27406
# Se han cargado ya 21000 de un total de 27406
# Nuevo producto insertado en BBDD: 'Echo (White)...' y se le ha asignado el ID 27
# Se han cargado ya 21100 de un total de 27406
# Se han cargado ya 21200 de un total de 27406
# Se han cargado ya 21300 de un total de 27406
# Se han cargado ya 21400 de un total de 27406
# Se han cargado ya 21500 de un total de 27406
# Row 21582 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 21600 de un total de 27406
# Se han cargado ya 21700 de un total de 27406
# Row 21794 da error. Se registra.     --> TypeError : must be real number, not dict
# Se han cargado ya 21800 de un total de 27406
# Se han cargado ya 21900 de un total de 27406
# Se han cargado ya 22000 de un total de 27406
# Se han cargado ya 22100 de un total de 27406
# Row 22180 da error. Se registra.     --> TypeError : must be real number, not dict
# Se han cargado ya 22200 de un total de 27406
# Se han cargado ya 22300 de un total de 27406
# Row 22383 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 22400 de un total de 27406
# Row 22415 da error. Se registra.     --> ValueError : unsupported format character 'm' (0x6d) at index 209
# Se han cargado ya 22500 de un total de 27406
# Se han cargado ya 22600 de un total de 27406
# Se han cargado ya 22700 de un total de 27406
# Se han cargado ya 22800 de un total de 27406
# Row 22815 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 22900 de un total de 27406
# Se han cargado ya 23000 de un total de 27406
# Se han cargado ya 23100 de un total de 27406
# Row 23151 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 23200 de un total de 27406
# Se han cargado ya 23300 de un total de 27406
# Row 23333 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 23400 de un total de 27406
# Row 23461 da error. Se registra.     --> ValueError : unsupported format character '!' (0x21) at index 687
# Row 23462 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Row 23498 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 23500 de un total de 27406
# Row 23594 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 23600 de un total de 27406
# Se han cargado ya 23700 de un total de 27406
# Se han cargado ya 23800 de un total de 27406
# Se han cargado ya 23900 de un total de 27406
# Se han cargado ya 24000 de un total de 27406
# Se han cargado ya 24100 de un total de 27406
# Se han cargado ya 24200 de un total de 27406
# Se han cargado ya 24300 de un total de 27406
# Row 24353 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Nuevo producto insertado en BBDD: 'Echo (Black)...' y se le ha asignado el ID 28
# Nuevo producto insertado en BBDD: 'Amazon 9W PowerFast Offic...' y se le ha asignado el ID 29
# Nuevo producto insertado en BBDD: 'Amazon Fire Hd 6 Standing...' y se le ha asignado el ID 30
# Se han cargado ya 24400 de un total de 27406
# Nuevo producto insertado en BBDD: 'Amazon Fire Hd 10 Tablet ...' y se le ha asignado el ID 31
# Se han cargado ya 24500 de un total de 27406
# Nuevo producto insertado en BBDD: 'Amazon - Amazon Tap Porta...' y se le ha asignado el ID 32
# Se han cargado ya 24600 de un total de 27406
# Se han cargado ya 24700 de un total de 27406
# Se han cargado ya 24800 de un total de 27406
# Nuevo producto insertado en BBDD: 'Coconut Water Red Tea 16....' y se le ha asignado el ID 33
# Nuevo producto insertado en BBDD: 'Amazon Fire Tv...' y se le ha asignado el ID 34
# Se han cargado ya 24900 de un total de 27406
# Row 24981 da error. Se registra.     --> TypeError : %c requires int or char
# Row 24985 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 25000 de un total de 27406
# Row 25008 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 25100 de un total de 27406
# Se han cargado ya 25200 de un total de 27406
# Se han cargado ya 25300 de un total de 27406
# Se han cargado ya 25400 de un total de 27406
# Se han cargado ya 25500 de un total de 27406
# Se han cargado ya 25600 de un total de 27406
# Row 25644 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 25700 de un total de 27406
# Se han cargado ya 25800 de un total de 27406
# Se han cargado ya 25900 de un total de 27406
# Se han cargado ya 26000 de un total de 27406
# Row 26076 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 26100 de un total de 27406
# Se han cargado ya 26200 de un total de 27406
# Se han cargado ya 26300 de un total de 27406
# Row 26357 da error. Se registra.     --> ValueError : unsupported format character 'p' (0x70) at index 82
# Se han cargado ya 26400 de un total de 27406
# Row 26408 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 26500 de un total de 27406
# Row 26564 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 26600 de un total de 27406
# Row 26656 da error. Se registra.     --> ValueError : unsupported format character '%' (0x25) at index 309
# Se han cargado ya 26700 de un total de 27406
# Row 26722 da error. Se registra.     --> TypeError : %o format: an integer is required, not dict
# Se han cargado ya 26800 de un total de 27406
# Se han cargado ya 26900 de un total de 27406
# Se han cargado ya 27000 de un total de 27406
# Se han cargado ya 27100 de un total de 27406
# Se han cargado ya 27200 de un total de 27406
# Row 27228 da error. Se registra.     --> ValueError : unsupported format character 'S' (0x53) at index 107
# Row 27277 da error. Se registra.     --> ValueError : unsupported format character 'p' (0x70) at index 605
# Se han cargado ya 27300 de un total de 27406
# Nuevo producto insertado en BBDD: 'Kindle Dx Leather Cover B...' y se le ha asignado el ID 35
# Nuevo producto insertado en BBDD: 'Amazon Kindle Fire 5ft US...' y se le ha asignado el ID 36
# Nuevo producto insertado en BBDD: 'New Amazon Kindle Fire Hd...' y se le ha asignado el ID 37
# Se han cargado ya 27400 de un total de 27406

# %%
len(ratings_que_dan_error)
# Out:
# 63

# %%
ratings_que_dan_error
# Out:
# [{'row': 581,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 't' (0x74) at index 165",)},
#  {'row': 606,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 727,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'b' (0x62) at index 1273",)},
#  {'row': 1323,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 't' (0x74) at index 335",)},
#  {'row': 1548,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'b' (0x62) at index 191",)},
#  {'row': 1632,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character ' ' (0x20) at index 211",)},
#  {'row': 2258,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 2643,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character ' ' (0x20) at index 237",)},
#  {'row': 2659,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character ' ' (0x20) at index 337",)},
#  {'row': 2870,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'b' (0x62) at index 2762",)},
#  {'row': 4012,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'S' (0x53) at index 111",)},
#  {'row': 4301,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 5249,
#   'error_type': 'TypeError',
#   'error_message': ('must be real number, not dict',)},
#  {'row': 5598,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 6815,
#   'error_type': 'TypeError',
#   'error_message': ('not enough arguments for format string',)},
#  {'row': 7461,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 7643,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 9015,
#   'error_type': 'TypeError',
#   'error_message': ('must be real number, not dict',)},
#  {'row': 9239,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 9587,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 9822,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character ')' (0x29) at index 1236",)},
#  {'row': 10685,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 11212,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 13495,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character ' ' (0x20) at index 65",)},
#  {'row': 14523,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'y' (0x79) at index 222",)},
#  {'row': 15299,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'K' (0x4b) at index 672",)},
#  {'row': 15858,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character ' ' (0x20) at index 490",)},
#  {'row': 17323,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character ' ' (0x20) at index 124",)},
#  {'row': 17863,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'm' (0x6d) at index 106",)},
#  {'row': 18200,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 18465,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character '!' (0x21) at index 459",)},
#  {'row': 18891,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'b' (0x62) at index 141",)},
#  {'row': 19654,
#   'error_type': 'TypeError',
#   'error_message': ('%c requires int or char',)},
#  {'row': 19840,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 20192,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'b' (0x62) at index 374",)},
#  {'row': 20566,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'b' (0x62) at index 443",)},
#  {'row': 20651,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 20685,
#   'error_type': 'TypeError',
#   'error_message': ('must be real number, not dict',)},
#  {'row': 21582,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 21794,
#   'error_type': 'TypeError',
#   'error_message': ('must be real number, not dict',)},
#  {'row': 22180,
#   'error_type': 'TypeError',
#   'error_message': ('must be real number, not dict',)},
#  {'row': 22383,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 22415,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'm' (0x6d) at index 209",)},
#  {'row': 22815,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 23151,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 23333,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 23461,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character '!' (0x21) at index 687",)},
#  {'row': 23462,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 23498,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 23594,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 24353,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 24981,
#   'error_type': 'TypeError',
#   'error_message': ('%c requires int or char',)},
#  {'row': 24985,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 25008,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 25644,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 26076,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 26357,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'p' (0x70) at index 82",)},
#  {'row': 26408,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 26564,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 26656,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character '%' (0x25) at index 309",)},
#  {'row': 26722,
#   'error_type': 'TypeError',
#   'error_message': ('%o format: an integer is required, not dict',)},
#  {'row': 27228,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'S' (0x53) at index 107",)},
#  {'row': 27277,
#   'error_type': 'ValueError',
#   'error_message': ("unsupported format character 'p' (0x70) at index 605",)}]

# %%
import json
ratings_error_json = json.dumps(ratings_que_dan_error)

# %%
with open("../data/rows_generating_erros.json", "w") as f:
   json.dump(ratings_que_dan_error, f)

# %%
ratings_error_json
# Out:
# '[{"row": 581, "error_type": "ValueError", "error_message": ["unsupported format character \'t\' (0x74) at index 165"]}, {"row": 606, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 727, "error_type": "ValueError", "error_message": ["unsupported format character \'b\' (0x62) at index 1273"]}, {"row": 1323, "error_type": "ValueError", "error_message": ["unsupported format character \'t\' (0x74) at index 335"]}, {"row": 1548, "error_type": "ValueError", "error_message": ["unsupported format character \'b\' (0x62) at index 191"]}, {"row": 1632, "error_type": "ValueError", "error_message": ["unsupported format character \' \' (0x20) at index 211"]}, {"row": 2258, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 2643, "error_type": "ValueError", "error_message": ["unsupported format character \' \' (0x20) at index 237"]}, {"row": 2659, "error_type": "ValueError", "error_message": ["unsupported format character \' \' (0x20) at index 337"]}, {"row": 2870, "error_type": "ValueError", "error_message": ["unsupported format character \'b\' (0x62) at index 2762"]}, {"row": 4012, "error_type": "ValueError", "error_message": ["unsupported format character \'S\' (0x53) at index 111"]}, {"row": 4301, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 5249, "error_type": "TypeError", "error_message": ["must be real number, not dict"]}, {"row": 5598, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 6815, "error_type": "TypeError", "error_message": ["not enough arguments for format string"]}, {"row": 7461, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 7643, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 9015, "error_type": "TypeError", "error_message": ["must be real number, not dict"]}, {"row": 9239, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 9587, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 9822, "error_type": "ValueError", "error_message": ["unsupported format character \')\' (0x29) at index 1236"]}, {"row": 10685, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 11212, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 13495, "error_type": "ValueError", "error_message": ["unsupported format character \' \' (0x20) at index 65"]}, {"row": 14523, "error_type": "ValueError", "error_message": ["unsupported format character \'y\' (0x79) at index 222"]}, {"row": 15299, "error_type": "ValueError", "error_message": ["unsupported format character \'K\' (0x4b) at index 672"]}, {"row": 15858, "error_type": "ValueError", "error_message": ["unsupported format character \' \' (0x20) at index 490"]}, {"row": 17323, "error_type": "ValueError", "error_message": ["unsupported format character \' \' (0x20) at index 124"]}, {"row": 17863, "error_type": "ValueError", "error_message": ["unsupported format character \'m\' (0x6d) at index 106"]}, {"row": 18200, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 18465, "error_type": "ValueError", "error_message": ["unsupported format character \'!\' (0x21) at index 459"]}, {"row": 18891, "error_type": "ValueError", "error_message": ["unsupported format character \'b\' (0x62) at index 141"]}, {"row": 19654, "error_type": "TypeError", "error_message": ["%c requires int or char"]}, {"row": 19840, "error_type": "TypeError", "error_message": ["%o format: an integer is required, not dict"]}, {"row": 20192, "error_type": "ValueError", "error_message": ["unsupported format character \'b\' (0x62) at index 374"]}, {"row": 20566, "error_type": " ...
